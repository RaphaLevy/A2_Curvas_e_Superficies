# %% [markdown]
# # A2 - Curvas e Superfícies

# %% [markdown]
# ## Alunos: Juliana Carvalho e Raphael Levy

# %%
# %display latex

# %% [markdown]
# ## Helicoide:

# %%
u, v = var('u,v', domain='real')
f = v*cos(u)
g = v*sin(u)
h = u
Helicoide = ParametrizedSurface3D((f, g, h), (u, v)); Helicoide
parametric_plot3d((f, g, h), (u,0,3*pi), (v,-pi,pi))
# Out:
# Graphics3d Object

# %%
print('f = v*cos(u)')
print('g = v*sin(u)')
print('h = u')

print(' ')
print('-------------------------------------------')
print(' ')

X_u = vector([diff(f, u), diff(g, u), diff(h, u)])
print(f'Primeira derivada (X_u): {X_u}')
print(' ')

X_uu = vector([diff(f, u, 2), diff(g, u, 2), diff(h, u, 2)])
print(f'Segunda derivada (X_uu): {X_uu}')


print(' ')
print('-------------------------------------------')
print(' ')

X_v = vector([diff(f, v), diff(g, v), diff(h, v)])
print(f'Primeira derivada (X_v): {X_v}')
print(' ')

X_vv = vector([diff(f, v, 2), diff(g, v, 2), diff(h, v, 2)])
print(f'Segunda derivada (X_vv): {X_vv}')

print(' ')
print('-------------------------------------------')
print(' ')

X_uv = vector([diff(f, u, v), diff(g, u, v), diff(h, u, v)])
print(f'Segunda derivada (X_uv): {X_uv}')
print(' ')

X_vu = vector([diff(f, v, u), diff(g, v, u), diff(h, v, u)])
print(f'Segunda derivada (X_vu): {X_vu}')
print(' ')
# Out:
# f = v*cos(u)
# g = v*sin(u)
# h = u
#
# -------------------------------------------
#
# Primeira derivada (X_u): (-v*sin(u), v*cos(u), 1)
#
# Segunda derivada (X_uu): (-v*cos(u), -v*sin(u), 0)
#
# -------------------------------------------
#
# Primeira derivada (X_v): (cos(u), sin(u), 0)
#
# Segunda derivada (X_vv): (0, 0, 0)
#
# -------------------------------------------
#
# Segunda derivada (X_uv): (-sin(u), cos(u), 0)
#
# Segunda derivada (X_vu): (-sin(u), cos(u), 0)

# %%
E = X_u.dot_product(X_u)
E

E_simple = E.simplify_full()
E_simple
# Out:
# v^2 + 1

# %%
print(E_simple)
# Out:
# v^2 + 1

# %%
F = X_u.dot_product(X_v)
F
# Out:
# 0

# %%
print(F)
# Out:
# 0

# %%
G = X_v.dot_product(X_v)
G

G_simple = G.simplify_full()
G_simple
# Out:
# 1

# %%
print(G_simple)
# Out:
# 1

# %%
cross_helic = X_u.cross_product(X_v)
cross_helic

cross_helic_simple = cross_helic.simplify_full()
cross_helic_simple
# Out:
# (-sin(u), cos(u), -v)

# %%
print(cross_helic_simple)
# Out:
# (-sin(u), cos(u), -v)

# %%
cross_helic_norm = cross_helic.norm(2)
cross_helic_norm

cross_helic_norm_simple = cross_helic_norm.simplify_full()
cross_helic_norm_simple
# Out:
# sqrt(v^2 + 1)

# %%
print(cross_helic_norm_simple)
# Out:
# sqrt(v^2 + 1)

# %%
N = (cross_helic)/(cross_helic_norm)
N

N_simple = N.simplify_full()
N_simple
# Out:
# (-sin(u)/sqrt(v^2 + 1), cos(u)/sqrt(v^2 + 1), -v/sqrt(v^2 + 1))

# %%
print(N_simple)
# Out:
# (-sin(u)/sqrt(v^2 + 1), cos(u)/sqrt(v^2 + 1), -v/sqrt(v^2 + 1))

# %%
e = N.dot_product(X_uu)
e
# Out:
# 0

# %%
print(e)
# Out:
# 0

# %%
f = N.dot_product(X_uv)
f

f_simple = f.simplify_full()
f_simple
# Out:
# 1/sqrt(v^2 + 1)

# %%
print(f_simple)
# Out:
# 1/sqrt(v^2 + 1)

# %%
g = N.dot_product(X_vv)
g
# Out:
# 0

# %%
print(g)
# Out:
# 0

# %% [markdown]
# ## Curvatura Gaussiana (K)

# %%
K_helic = (e*g - f^2)/(E*G - F^2)
K_helic

K_helic_simple = K_helic.simplify_full()
K_helic_simple
# Out:
# -1/(v^4 + 2*v^2 + 1)

# %%
print(K_helic_simple)
# Out:
# -1/(v^4 + 2*v^2 + 1)

# %% [markdown]
# ## Curvatura Média (H)

# %%
H_helic = (e*G - 2*f*F + g*E)/(2*(E*G - F^2))
H_helic
# Out:
# 0

# %%
print(H_helic)
# Out:
# 0

# %% [markdown]
# ## Catenoide:

# %%
u, v = var('u,v', domain='real')
f = cos(u)*cosh(v)
g = cosh(v)*sin(u)
h = v
Catenoide = ParametrizedSurface3D((f, g, h), (u, v)); Catenoide
parametric_plot3d((f, g, h), (u,0,2*pi), (v,-pi/2,pi/2), color = 'green')
# Out:
# Graphics3d Object

# %%
print('f = cos(u)*cosh(v)')
print('g = cosh(v)*sin(u)')
print('h = v')

print(' ')
print('-------------------------------------------')
print(' ')

X_u = vector([diff(f, u), diff(g, u), diff(h, u)])
print(f'Primeira derivada (X_u): {X_u}')
print(' ')

X_uu = vector([diff(f, u, 2), diff(g, u, 2), diff(h, u, 2)])
print(f'Segunda derivada (X_uu): {X_uu}')


print(' ')
print('-------------------------------------------')
print(' ')

X_v = vector([diff(f, v), diff(g, v), diff(h, v)])
print(f'Primeira derivada (X_v): {X_v}')
print(' ')

X_vv = vector([diff(f, v, 2), diff(g, v, 2), diff(h, v, 2)])
print(f'Segunda derivada (X_vv): {X_vv}')

print(' ')
print('-------------------------------------------')
print(' ')

X_uv = vector([diff(f, u, v), diff(g, u, v), diff(h, u, v)])
print(f'Segunda derivada (X_uv): {X_uv}')
print(' ')

X_vu = vector([diff(f, v, u), diff(g, v, u), diff(h, v, u)])
print(f'Segunda derivada (X_vu): {X_vu}')
print(' ')
# Out:
# f = cos(u)*cosh(v)
# g = cosh(v)*sin(u)
# h = v
#
# -------------------------------------------
#
# Primeira derivada (X_u): (-cosh(v)*sin(u), cos(u)*cosh(v), 0)
#
# Segunda derivada (X_uu): (-cos(u)*cosh(v), -cosh(v)*sin(u), 0)
#
# -------------------------------------------
#
# Primeira derivada (X_v): (cos(u)*sinh(v), sin(u)*sinh(v), 1)
#
# Segunda derivada (X_vv): (cos(u)*cosh(v), cosh(v)*sin(u), 0)
#
# -------------------------------------------
#
# Segunda derivada (X_uv): (-sin(u)*sinh(v), cos(u)*sinh(v), 0)
#
# Segunda derivada (X_vu): (-sin(u)*sinh(v), cos(u)*sinh(v), 0)

# %%
E = X_u.dot_product(X_u)
E

E_simple = E.simplify_full()
E_simple
# Out:
# cosh(v)^2

# %%
print(E_simple)
# Out:
# cosh(v)^2

# %%
F = X_u.dot_product(X_v)
F
# Out:
# 0

# %%
print(F)
# Out:
# 0

# %%
G = X_v.dot_product(X_v)
G

G_simple = G.simplify_full()
G_simple
# Out:
# cosh(v)^2

# %%
print(G_simple)
# Out:
# cosh(v)^2

# %%
cross_cat = X_u.cross_product(X_v)
cross_cat

cross_cat_simple = cross_cat.simplify_full()
cross_cat_simple
# Out:
# (cos(u)*cosh(v), cosh(v)*sin(u), -cosh(v)*sinh(v))

# %%
print(cross_cat_simple)
# Out:
# (cos(u)*cosh(v), cosh(v)*sin(u), -cosh(v)*sinh(v))

# %%
cross_cat_norm = cross_cat.norm(2)
cross_cat_norm

cross_cat_norm_simple = cross_cat_norm.simplify_full()
cross_cat_norm_simple
# Out:
# cosh(v)^2

# %%
print(cross_cat_norm_simple)
# Out:
# cosh(v)^2

# %%
N = (cross_cat)/(cross_cat_norm)
N

N_simple = N.simplify_full()
N_simple
# Out:
# (cos(u)/cosh(v), sin(u)/cosh(v), -sinh(v)/cosh(v))

# %%
print(N_simple)
# Out:
# (cos(u)/cosh(v), sin(u)/cosh(v), -sinh(v)/cosh(v))

# %%
e = N.dot_product(X_uu)
e

e_simple = e.simplify_full()
e_simple
# Out:
# -1

# %%
print(e_simple)
# Out:
# -1

# %%
f = N.dot_product(X_uv)
f
# Out:
# 0

# %%
print(f)
# Out:
# 0

# %%
g = N.dot_product(X_vv)
g

g_simple = g.simplify_full()
g_simple
# Out:
# 1

# %%
print(g_simple)
# Out:
# 1

# %% [markdown]
# ## Curvatura Gaussiana (K)

# %%
K_cat = (e*g - f^2)/(E*G - F^2)
K_cat

K_cat_simple = K_cat.simplify_full()
K_cat_simple
# Out:
# -1/cosh(v)^4

# %%
print(K_cat_simple)
# Out:
# -1/cosh(v)^4

# %% [markdown]
# ## Curvatura Média (H)

# %%
H_cat = (e*G - 2*f*F + g*E)/(2*(E*G - F^2))
H_cat

H_cat_simple = H_cat.simplify_full()
H_cat_simple
# Out:
# 0

# %%
print(H_cat_simple)
# Out:
# 0

# %% [markdown]
# ## Esfera:

# %%
u, v = var('u,v', domain='real')
f = sin(u)*cos(v)
g = sin(u)*sin(v)
h = cos(u)
Esfera = ParametrizedSurface3D((f, g, h), (u, v)); Esfera
parametric_plot3d((f, g, h), (u,0,pi), (v,0, 2*pi), color = 'purple')
# Out:
# Graphics3d Object

# %%
print('f = sin(u)*cos(v)')
print('g = sin(u)*sin(v)')
print('h = cos(u)')

print(' ')
print('-------------------------------------------')
print(' ')

X_u = vector([diff(f, u), diff(g, u), diff(h, u)])
print(f'Primeira derivada (X_u): {X_u}')
print(' ')

X_uu = vector([diff(f, u, 2), diff(g, u, 2), diff(h, u, 2)])
print(f'Segunda derivada (X_uu): {X_uu}')


print(' ')
print('-------------------------------------------')
print(' ')

X_v = vector([diff(f, v), diff(g, v), diff(h, v)])
print(f'Primeira derivada (X_v): {X_v}')
print(' ')

X_vv = vector([diff(f, v, 2), diff(g, v, 2), diff(h, v, 2)])
print(f'Segunda derivada (X_vv): {X_vv}')

print(' ')
print('-------------------------------------------')
print(' ')

X_uv = vector([diff(f, u, v), diff(g, u, v), diff(h, u, v)])
print(f'Segunda derivada (X_uv): {X_uv}')
print(' ')

X_vu = vector([diff(f, v, u), diff(g, v, u), diff(h, v, u)])
print(f'Segunda derivada (X_vu): {X_vu}')
print(' ')
# Out:
# f = sin(u)*cos(v)
# g = sin(u)*sin(v)
# h = cos(u)
#
# -------------------------------------------
#
# Primeira derivada (X_u): (cos(u)*cos(v), cos(u)*sin(v), -sin(u))
#
# Segunda derivada (X_uu): (-cos(v)*sin(u), -sin(u)*sin(v), -cos(u))
#
# -------------------------------------------
#
# Primeira derivada (X_v): (-sin(u)*sin(v), cos(v)*sin(u), 0)
#
# Segunda derivada (X_vv): (-cos(v)*sin(u), -sin(u)*sin(v), 0)
#
# -------------------------------------------
#
# Segunda derivada (X_uv): (-cos(u)*sin(v), cos(u)*cos(v), 0)
#
# Segunda derivada (X_vu): (-cos(u)*sin(v), cos(u)*cos(v), 0)

# %%
E = X_u.dot_product(X_u)
E

E_simple = E.simplify_full()
E_simple
# Out:
# 1

# %%
print(E_simple)
# Out:
# 1

# %%
F = X_u.dot_product(X_v)
F
# Out:
# 0

# %%
print(F)
# Out:
# 0

# %%
G = X_v.dot_product(X_v)
G

G_simple = G.simplify_full()
G_simple
# Out:
# sin(u)^2

# %%
print(G_simple)
# Out:
# sin(u)^2

# %%
cross_esf = X_u.cross_product(X_v)
cross_esf

cross_esf_simple = cross_esf.simplify_full()
cross_esf_simple
# Out:
# (cos(v)*sin(u)^2, sin(u)^2*sin(v), cos(u)*sin(u))

# %%
print(cross_esf_simple)
# Out:
# (cos(v)*sin(u)^2, sin(u)^2*sin(v), cos(u)*sin(u))

# %%
cross_esf_norm = cross_esf.norm(2)
cross_esf_norm

cross_esf_norm_simple = cross_esf_norm.simplify_full()
cross_esf_norm_simple
# Out:
# abs(sin(u))

# %%
print(cross_esf_norm_simple)
# Out:
# abs(sin(u))

# %%
N = (cross_esf)/(cross_esf_norm)
N

N_simple = N.simplify_full()
N_simple
# Out:
# (abs(sin(u))*cos(v), abs(sin(u))*sin(v), cos(u)*sin(u)/abs(sin(u)))

# %%
print(N_simple)
# Out:
# (abs(sin(u))*cos(v), abs(sin(u))*sin(v), cos(u)*sin(u)/abs(sin(u)))

# %%
e = N.dot_product(X_uu)
e

e_simple = e.simplify_full()
e_simple
# Out:
# -sin(u)/abs(sin(u))

# %%
print(e_simple)
# Out:
# -sin(u)/abs(sin(u))

# %%
f = N.dot_product(X_uv)
f
# Out:
# 0

# %%
print(f)
# Out:
# 0

# %%
g = N.dot_product(X_vv)
g

g_simple = g.simplify_full()
g_simple
# Out:
# -abs(sin(u))*sin(u)

# %%
print(g_simple)
# Out:
# -abs(sin(u))*sin(u)

# %% [markdown]
# ## Curvatura Gaussiana (K)

# %%
K_esf = (e*g - f^2)/(E*G - F^2)
K_esf

K_esf_simple = K_esf.simplify_full()
K_esf_simple
# Out:
# 1

# %%
print(K_esf_simple)
# Out:
# 1

# %% [markdown]
# ## Curvatura Média (H)

# %%
H_esf = (e*G - 2*f*F + g*E)/(2*(E*G - F^2))
H_esf

H_esf_simple = H_esf.simplify_full()
H_esf_simple
# Out:
# -sin(u)/abs(sin(u))

# %%
print(H_esf_simple)
# Out:
# -sin(u)/abs(sin(u))

# %% [markdown]
# ## Superfície de Enneper:

# %%
u, v = var('u,v', domain='real')
f = u - (u^3)/3 + u*(v^2)
g = v - (v^3)/3 + v*(u^2)
h = u^2 - v^2
Enneper = ParametrizedSurface3D((f, g, h), (u, v)); Enneper
parametric_plot3d((f, g, h), (u,-5, 5), (v,-5, 5), color = 'lime')
# Out:
# Graphics3d Object

# %%
print('f = u - (u^3)/3 + u*(v^2)')
print('g = -v + (v^3)/3 - v*(u^2)')
print('h = u^2 - v^2')

print(' ')
print('-------------------------------------------')
print(' ')

X_u = vector([diff(f, u), diff(g, u), diff(h, u)])
print(f'Primeira derivada (X_u): {X_u}')
print(' ')

X_uu = vector([diff(f, u, 2), diff(g, u, 2), diff(h, u, 2)])
print(f'Segunda derivada (X_uu): {X_uu}')


print(' ')
print('-------------------------------------------')
print(' ')

X_v = vector([diff(f, v), diff(g, v), diff(h, v)])
print(f'Primeira derivada (X_v): {X_v}')
print(' ')

X_vv = vector([diff(f, v, 2), diff(g, v, 2), diff(h, v, 2)])
print(f'Segunda derivada (X_vv): {X_vv}')

print(' ')
print('-------------------------------------------')
print(' ')

X_uv = vector([diff(f, u, v), diff(g, u, v), diff(h, u, v)])
print(f'Segunda derivada (X_uv): {X_uv}')
print(' ')

X_vu = vector([diff(f, v, u), diff(g, v, u), diff(h, v, u)])
print(f'Segunda derivada (X_vu): {X_vu}')
print(' ')
# Out:
# f = u - (u^3)/3 + u*(v^2)
# g = -v + (v^3)/3 - v*(u^2)
# h = u^2 - v^2
#
# -------------------------------------------
#
# Primeira derivada (X_u): (-u^2 + v^2 + 1, 2*u*v, 2*u)
#
# Segunda derivada (X_uu): (-2*u, 2*v, 2)
#
# -------------------------------------------
#
# Primeira derivada (X_v): (2*u*v, u^2 - v^2 + 1, -2*v)
#
# Segunda derivada (X_vv): (2*u, -2*v, -2)
#
# -------------------------------------------
#
# Segunda derivada (X_uv): (2*v, 2*u, 0)
#
# Segunda derivada (X_vu): (2*v, 2*u, 0)

# %%
E = X_u.dot_product(X_u)
E

E_simple = E.simplify_full()
E_simple
# Out:
# u^4 + v^4 + 2*(u^2 + 1)*v^2 + 2*u^2 + 1

# %%
print(E_simple)
# Out:
# u^4 + v^4 + 2*(u^2 + 1)*v^2 + 2*u^2 + 1

# %%
F = X_u.dot_product(X_v)
F

F_simple = F.simplify_full()
F_simple
# Out:
# 0

# %%
print(F_simple)
# Out:
# 0

# %%
G = X_v.dot_product(X_v)
G

G_simple = G.simplify_full()
G_simple
# Out:
# u^4 + v^4 + 2*(u^2 + 1)*v^2 + 2*u^2 + 1

# %%
print(G_simple)
# Out:
# u^4 + v^4 + 2*(u^2 + 1)*v^2 + 2*u^2 + 1

# %%
cross_enneper = X_u.cross_product(X_v)
cross_enneper

cross_enneper_simple = cross_enneper.simplify_full()
cross_enneper_simple
# Out:
# (-2*u^3 - 2*u*v^2 - 2*u, 2*v^3 + 2*(u^2 + 1)*v, -u^4 - 2*u^2*v^2 - v^4 + 1)

# %%
print(cross_enneper_simple)
# Out:
# (-2*u^3 - 2*u*v^2 - 2*u, 2*v^3 + 2*(u^2 + 1)*v, -u^4 - 2*u^2*v^2 - v^4 + 1)

# %%
cross_enneper_norm = cross_enneper.norm(2)
cross_enneper_norm

cross_enneper_norm_simple = cross_enneper_norm.simplify_full()
cross_enneper_norm_simple
# Out:
# sqrt(u^8 + v^8 + 4*(u^2 + 1)*v^6 + 4*u^6 + 6*(u^4 + 2*u^2 + 1)*v^4 + 6*u^4 + 4*(u^6 + 3*u^4 + 3*u^2 + 1)*v^2 + 4*u^2 + 1)

# %%
print(cross_enneper_norm_simple)
# Out:
# sqrt(u^8 + v^8 + 4*(u^2 + 1)*v^6 + 4*u^6 + 6*(u^4 + 2*u^2 + 1)*v^4 + 6*u^4 + 4*(u^6 + 3*u^4 + 3*u^2 + 1)*v^2 + 4*u^2 + 1)

# %%
N = (cross_enneper)/(cross_enneper_norm)
N

N_simple = N.simplify_full()
N_simple
# Out:
# (-2*(u^3 + u*v^2 + u)/sqrt(u^8 + v^8 + 4*(u^2 + 1)*v^6 + 4*u^6 + 6*(u^4 + 2*u^2 + 1)*v^4 + 6*u^4 + 4*(u^6 + 3*u^4 + 3*u^2 + 1)*v^2 + 4*u^2 + 1), 2*(v^3 + (u^2 + 1)*v)/sqrt(u^8 + v^8 + 4*(u^2 + 1)*v^6 + 4*u^6 + 6*(u^4 + 2*u^2 + 1)*v^4 + 6*u^4 + 4*(u^6 + 3*u^4 + 3*u^2 + 1)*v^2 + 4*u^2 + 1), -(u^4 + 2*u^2*v^2 + v^4 - 1)/sqrt(u^8 + v^8 + 4*(u^2 + 1)*v^6 + 4*u^6 + 6*(u^4 + 2*u^2 + 1)*v^4 + 6*u^4 + 4*(u^6 + 3*u^4 + 3*u^2 + 1)*v^2 + 4*u^2 + 1))

# %%
print(N_simple)
# Out:
# (-2*(u^3 + u*v^2 + u)/sqrt(u^8 + v^8 + 4*(u^2 + 1)*v^6 + 4*u^6 + 6*(u^4 + 2*u^2 + 1)*v^4 + 6*u^4 + 4*(u^6 + 3*u^4 + 3*u^2 + 1)*v^2 + 4*u^2 + 1), 2*(v^3 + (u^2 + 1)*v)/sqrt(u^8 + v^8 + 4*(u^2 + 1)*v^6 + 4*u^6 + 6*(u^4 + 2*u^2 + 1)*v^4 + 6*u^4 + 4*(u^6 + 3*u^4 + 3*u^2 + 1)*v^2 + 4*u^2 + 1), -(u^4 + 2*u^2*v^2 + v^4 - 1)/sqrt(u^8 + v^8 + 4*(u^2 + 1)*v^6 + 4*u^6 + 6*(u^4 + 2*u^2 + 1)*v^4 + 6*u^4 + 4*(u^6 + 3*u^4 + 3*u^2 + 1)*v^2 + 4*u^2 + 1))

# %%
e = N.dot_product(X_uu)
e

e_simple = e.simplify_full()
e_simple
# Out:
# 2*(u^4 + v^4 + 2*(u^2 + 1)*v^2 + 2*u^2 + 1)/sqrt(u^8 + v^8 + 4*(u^2 + 1)*v^6 + 4*u^6 + 6*(u^4 + 2*u^2 + 1)*v^4 + 6*u^4 + 4*(u^6 + 3*u^4 + 3*u^2 + 1)*v^2 + 4*u^2 + 1)

# %%
print(e_simple)
# Out:
# 2*(u^4 + v^4 + 2*(u^2 + 1)*v^2 + 2*u^2 + 1)/sqrt(u^8 + v^8 + 4*(u^2 + 1)*v^6 + 4*u^6 + 6*(u^4 + 2*u^2 + 1)*v^4 + 6*u^4 + 4*(u^6 + 3*u^4 + 3*u^2 + 1)*v^2 + 4*u^2 + 1)

# %%
f = N.dot_product(X_uv)
f

f_simple = f.simplify_full()
f_simple
# Out:
# 0

# %%
print(f_simple)
# Out:
# 0

# %%
g = N.dot_product(X_vv)
g

g_simple = g.simplify_full()
g_simple
# Out:
# -2*(u^4 + v^4 + 2*(u^2 + 1)*v^2 + 2*u^2 + 1)/sqrt(u^8 + v^8 + 4*(u^2 + 1)*v^6 + 4*u^6 + 6*(u^4 + 2*u^2 + 1)*v^4 + 6*u^4 + 4*(u^6 + 3*u^4 + 3*u^2 + 1)*v^2 + 4*u^2 + 1)

# %%
print(g_simple)
# Out:
# -2*(u^4 + v^4 + 2*(u^2 + 1)*v^2 + 2*u^2 + 1)/sqrt(u^8 + v^8 + 4*(u^2 + 1)*v^6 + 4*u^6 + 6*(u^4 + 2*u^2 + 1)*v^4 + 6*u^4 + 4*(u^6 + 3*u^4 + 3*u^2 + 1)*v^2 + 4*u^2 + 1)

# %% [markdown]
# ## Curvatura Gaussiana (K)

# %%
K_enneper = (e*g - f^2)/(E*G - F^2)
K_enneper

K_enneper_simple = K_enneper.simplify_full()
K_enneper_simple
# Out:
# -4/(u^8 + v^8 + 4*(u^2 + 1)*v^6 + 4*u^6 + 6*(u^4 + 2*u^2 + 1)*v^4 + 6*u^4 + 4*(u^6 + 3*u^4 + 3*u^2 + 1)*v^2 + 4*u^2 + 1)

# %%
print(K_enneper_simple)
# Out:
# -4/(u^8 + v^8 + 4*(u^2 + 1)*v^6 + 4*u^6 + 6*(u^4 + 2*u^2 + 1)*v^4 + 6*u^4 + 4*(u^6 + 3*u^4 + 3*u^2 + 1)*v^2 + 4*u^2 + 1)

# %% [markdown]
# ## Curvatura Média (H)

# %%
H_enneper = (e*G - 2*f*F + g*E)/(2*(E*G - F^2))
H_enneper

H_enneper_simple = H_enneper.simplify_full()
H_enneper_simple
# Out:
# 0

# %%
print(H_enneper_simple)
# Out:
# 0

# %% [markdown]
# ## Fita de Möbius

# %%
u, v = var('u,v', domain='real')
f = cos(u)*(1+v*cos(u/2))
g = sin(u)*(1+v*cos(u/2))
h = v*sin(u/2)
Mobius = ParametrizedSurface3D((f, g, h), (u, v)); Mobius
parametric_plot3d((f, g, h), (u,0, 2*pi), (v,-0.5, 0.5), color = 'goldenrod')
# Out:
# Graphics3d Object

# %%
print('f = cos(u)*(1+v*cos(u/2))')
print('g = sin(u)*(1+v*cos(u/2))')
print('h = v*sin(u/2)')

print(' ')
print('-------------------------------------------')
print(' ')

X_u = vector([diff(f, u), diff(g, u), diff(h, u)])
print(f'Primeira derivada (X_u): {X_u}')
print(' ')

X_uu = vector([diff(f, u, 2), diff(g, u, 2), diff(h, u, 2)])
print(f'Segunda derivada (X_uu): {X_uu}')


print(' ')
print('-------------------------------------------')
print(' ')

X_v = vector([diff(f, v), diff(g, v), diff(h, v)])
print(f'Primeira derivada (X_v): {X_v}')
print(' ')

X_vv = vector([diff(f, v, 2), diff(g, v, 2), diff(h, v, 2)])
print(f'Segunda derivada (X_vv): {X_vv}')

print(' ')
print('-------------------------------------------')
print(' ')

X_uv = vector([diff(f, u, v), diff(g, u, v), diff(h, u, v)])
print(f'Segunda derivada (X_uv): {X_uv}')
print(' ')

X_vu = vector([diff(f, v, u), diff(g, v, u), diff(h, v, u)])
print(f'Segunda derivada (X_vu): {X_vu}')
print(' ')
# Out:
# f = cos(u)*(1+v*cos(u/2))
# g = sin(u)*(1+v*cos(u/2))
# h = v*sin(u/2)
#
# -------------------------------------------
#
# Primeira derivada (X_u): (-1/2*v*cos(u)*sin(1/2*u) - (v*cos(1/2*u) + 1)*sin(u), -1/2*v*sin(1/2*u)*sin(u) + (v*cos(1/2*u) + 1)*cos(u), 1/2*v*cos(1/2*u))
#
# Segunda derivada (X_uu): (-1/4*v*cos(1/2*u)*cos(u) + v*sin(1/2*u)*sin(u) - (v*cos(1/2*u) + 1)*cos(u), -v*cos(u)*sin(1/2*u) - 1/4*v*cos(1/2*u)*sin(u) - (v*cos(1/2*u) + 1)*sin(u), -1/4*v*sin(1/2*u))
#
# -------------------------------------------
#
# Primeira derivada (X_v): (cos(1/2*u)*cos(u), cos(1/2*u)*sin(u), sin(1/2*u))
#
# Segunda derivada (X_vv): (0, 0, 0)
#
# -------------------------------------------
#
# Segunda derivada (X_uv): (-1/2*cos(u)*sin(1/2*u) - cos(1/2*u)*sin(u), cos(1/2*u)*cos(u) - 1/2*sin(1/2*u)*sin(u), 1/2*cos(1/2*u))
#
# Segunda derivada (X_vu): (-1/2*cos(u)*sin(1/2*u) - cos(1/2*u)*sin(u), cos(1/2*u)*cos(u) - 1/2*sin(1/2*u)*sin(u), 1/2*cos(1/2*u))

# %%
E = X_u.dot_product(X_u)
E

E_simple = E.simplify_full()
E_simple
# Out:
# 1/4*(4*cos(1/2*u)^2 + 1)*v^2 + 2*v*cos(1/2*u) + 1

# %%
print(E_simple)
# Out:
# 1/4*(4*cos(1/2*u)^2 + 1)*v^2 + 2*v*cos(1/2*u) + 1

# %%
F = X_u.dot_product(X_v)
F

F_simple = F.simplify_full()
F_simple
# Out:
# 0

# %%
print(F_simple)
# Out:
# 0

# %%
G = X_v.dot_product(X_v)
G

G_simple = G.simplify_full()
G_simple
# Out:
# 1

# %%
print(G_simple)
# Out:
# 1

# %%
cross_mobius = X_u.cross_product(X_v)
cross_mobius

cross_mobius_simple = cross_mobius.simplify_full()
cross_mobius_simple
# Out:
# (1/2*(2*cos(1/2*u)*cos(u)*sin(1/2*u) - sin(u))*v + cos(u)*sin(1/2*u), 1/2*(2*cos(1/2*u)*sin(1/2*u)*sin(u) + cos(u))*v + sin(1/2*u)*sin(u), -v*cos(1/2*u)^2 - cos(1/2*u))

# %%
print(cross_mobius_simple)
# Out:
# (1/2*(2*cos(1/2*u)*cos(u)*sin(1/2*u) - sin(u))*v + cos(u)*sin(1/2*u), 1/2*(2*cos(1/2*u)*sin(1/2*u)*sin(u) + cos(u))*v + sin(1/2*u)*sin(u), -v*cos(1/2*u)^2 - cos(1/2*u))

# %%
cross_mobius_norm = cross_mobius.norm(2)
cross_mobius_norm

cross_mobius_norm_simple = cross_mobius_norm.simplify_full()
cross_mobius_norm_simple
# Out:
# 1/2*sqrt((4*cos(1/2*u)^2 + 1)*v^2 + 8*v*cos(1/2*u) + 4)

# %%
print(cross_mobius_norm_simple)
# Out:
# 1/2*sqrt((4*cos(1/2*u)^2 + 1)*v^2 + 8*v*cos(1/2*u) + 4)

# %%
N = (cross_mobius)/(cross_mobius_norm)
N

N_simple = N.simplify_full()
N_simple
# Out:
# (((2*cos(1/2*u)*cos(u)*sin(1/2*u) - sin(u))*v + 2*cos(u)*sin(1/2*u))/sqrt((4*cos(1/2*u)^2 + 1)*v^2 + 8*v*cos(1/2*u) + 4), ((2*cos(1/2*u)*sin(1/2*u)*sin(u) + cos(u))*v + 2*sin(1/2*u)*sin(u))/sqrt((4*cos(1/2*u)^2 + 1)*v^2 + 8*v*cos(1/2*u) + 4), -2*(v*cos(1/2*u)^2 + cos(1/2*u))/sqrt((4*cos(1/2*u)^2 + 1)*v^2 + 8*v*cos(1/2*u) + 4))

# %%
print(N_simple)
# Out:
# (((2*cos(1/2*u)*cos(u)*sin(1/2*u) - sin(u))*v + 2*cos(u)*sin(1/2*u))/sqrt((4*cos(1/2*u)^2 + 1)*v^2 + 8*v*cos(1/2*u) + 4), ((2*cos(1/2*u)*sin(1/2*u)*sin(u) + cos(u))*v + 2*sin(1/2*u)*sin(u))/sqrt((4*cos(1/2*u)^2 + 1)*v^2 + 8*v*cos(1/2*u) + 4), -2*(v*cos(1/2*u)^2 + cos(1/2*u))/sqrt((4*cos(1/2*u)^2 + 1)*v^2 + 8*v*cos(1/2*u) + 4))

# %%
e = N.dot_product(X_uu)
e

e_simple = e.simplify_full()
e_simple
# Out:
# -((2*cos(1/2*u)^2 + 1)*v^2*sin(1/2*u) + 4*v*cos(1/2*u)*sin(1/2*u) + 2*sin(1/2*u))/sqrt((4*cos(1/2*u)^2 + 1)*v^2 + 8*v*cos(1/2*u) + 4)

# %%
print(e_simple)
# Out:
# -((2*cos(1/2*u)^2 + 1)*v^2*sin(1/2*u) + 4*v*cos(1/2*u)*sin(1/2*u) + 2*sin(1/2*u))/sqrt((4*cos(1/2*u)^2 + 1)*v^2 + 8*v*cos(1/2*u) + 4)

# %%
f = N.dot_product(X_uv)
f

f_simple = f.simplify_full()
f_simple
# Out:
# -1/sqrt((4*cos(1/2*u)^2 + 1)*v^2 + 8*v*cos(1/2*u) + 4)

# %%
print(f_simple)
# Out:
# -1/sqrt((4*cos(1/2*u)^2 + 1)*v^2 + 8*v*cos(1/2*u) + 4)

# %%
g = N.dot_product(X_vv)
g

g_simple = g.simplify_full()
g_simple
# Out:
# 0

# %%
print(g_simple)
# Out:
# 0

# %% [markdown]
# ## Curvatura Gaussiana (K)

# %%
K_mobius = (e*g - f^2)/(E*G - F^2)
K_mobius

K_mobius_simple = K_mobius.simplify_full()
K_mobius_simple
# Out:
# -4/((16*cos(1/2*u)^4 + 8*cos(1/2*u)^2 + 1)*v^4 + 16*(4*cos(1/2*u)^3 + cos(1/2*u))*v^3 + 8*(12*cos(1/2*u)^2 + 1)*v^2 + 64*v*cos(1/2*u) + 16)

# %%
print(K_mobius_simple)
# Out:
# -4/((16*cos(1/2*u)^4 + 8*cos(1/2*u)^2 + 1)*v^4 + 16*(4*cos(1/2*u)^3 + cos(1/2*u))*v^3 + 8*(12*cos(1/2*u)^2 + 1)*v^2 + 64*v*cos(1/2*u) + 16)

# %% [markdown]
# ## Curvatura Média (H)

# %%
H_mobius = (e*G - 2*f*F + g*E)/(2*(E*G - F^2))
H_mobius

H_mobius_simple = H_mobius.simplify_full()
H_mobius_simple
# Out:
# -2*((2*cos(1/2*u)^2 + 1)*v^2*sin(1/2*u) + 4*v*cos(1/2*u)*sin(1/2*u) + 2*sin(1/2*u))*sqrt((4*cos(1/2*u)^2 + 1)*v^2 + 8*v*cos(1/2*u) + 4)/((16*cos(1/2*u)^4 + 8*cos(1/2*u)^2 + 1)*v^4 + 16*(4*cos(1/2*u)^3 + cos(1/2*u))*v^3 + 8*(12*cos(1/2*u)^2 + 1)*v^2 + 64*v*cos(1/2*u) + 16)

# %%
print(H_mobius_simple)
# Out:
# -2*((2*cos(1/2*u)^2 + 1)*v^2*sin(1/2*u) + 4*v*cos(1/2*u)*sin(1/2*u) + 2*sin(1/2*u))*sqrt((4*cos(1/2*u)^2 + 1)*v^2 + 8*v*cos(1/2*u) + 4)/((16*cos(1/2*u)^4 + 8*cos(1/2*u)^2 + 1)*v^4 + 16*(4*cos(1/2*u)^3 + cos(1/2*u))*v^3 + 8*(12*cos(1/2*u)^2 + 1)*v^2 + 64*v*cos(1/2*u) + 16)

# %% [markdown]
# ## Superfície de Catalan:

# %%
u, v = var('u,v', domain='real')
f = 2*v - sin(2*v)*cosh(2*u)
g = cos(2*v)*cosh(2*u)
h = 4*sin(v)*sinh(u)
Catalan = ParametrizedSurface3D((f, g, h), (u, v)); Catalan
parametric_plot3d((f, g, h), (u,0, pi), (v,0, 3*pi), color = 'turquoise')
# Out:
# Graphics3d Object

# %%
print('f = u - sin(u)*cosh(v)')
print('g = 1 - cos(u)*cosh(v)')
print('h = 4*sin(u/2)*sinh(v/2)')

print(' ')
print('-------------------------------------------')
print(' ')

X_u = vector([diff(f, u), diff(g, u), diff(h, u)])
print(f'Primeira derivada (X_u): {X_u}')
print(' ')

X_uu = vector([diff(f, u, 2), diff(g, u, 2), diff(h, u, 2)])
print(f'Segunda derivada (X_uu): {X_uu}')


print(' ')
print('-------------------------------------------')
print(' ')

X_v = vector([diff(f, v), diff(g, v), diff(h, v)])
print(f'Primeira derivada (X_v): {X_v}')
print(' ')

X_vv = vector([diff(f, v, 2), diff(g, v, 2), diff(h, v, 2)])
print(f'Segunda derivada (X_vv): {X_vv}')

print(' ')
print('-------------------------------------------')
print(' ')

X_uv = vector([diff(f, u, v), diff(g, u, v), diff(h, u, v)])
print(f'Segunda derivada (X_uv): {X_uv}')
print(' ')

X_vu = vector([diff(f, v, u), diff(g, v, u), diff(h, v, u)])
print(f'Segunda derivada (X_vu): {X_vu}')
print(' ')
# Out:
# f = u - sin(u)*cosh(v)
# g = 1 - cos(u)*cosh(v)
# h = 4*sin(u/2)*sinh(v/2)
#
# -------------------------------------------
#
# Primeira derivada (X_u): (-2*sin(2*v)*sinh(2*u), 2*cos(2*v)*sinh(2*u), 4*cosh(u)*sin(v))
#
# Segunda derivada (X_uu): (-4*cosh(2*u)*sin(2*v), 4*cos(2*v)*cosh(2*u), 4*sin(v)*sinh(u))
#
# -------------------------------------------
#
# Primeira derivada (X_v): (-2*cos(2*v)*cosh(2*u) + 2, -2*cosh(2*u)*sin(2*v), 4*cos(v)*sinh(u))
#
# Segunda derivada (X_vv): (4*cosh(2*u)*sin(2*v), -4*cos(2*v)*cosh(2*u), -4*sin(v)*sinh(u))
#
# -------------------------------------------
#
# Segunda derivada (X_uv): (-4*cos(2*v)*sinh(2*u), -4*sin(2*v)*sinh(2*u), 4*cos(v)*cosh(u))
#
# Segunda derivada (X_vu): (-4*cos(2*v)*sinh(2*u), -4*sin(2*v)*sinh(2*u), 4*cos(v)*cosh(u))

# %%
E = X_u.dot_product(X_u)
E

E_simple = E.simplify_full()
E_simple
# Out:
# -16*cos(v)^2*cosh(u)^2 + 16*cosh(u)^4

# %%
print(E_simple)
# Out:
# -16*cos(v)^2*cosh(u)^2 + 16*cosh(u)^4

# %%
F = X_u.dot_product(X_v)
F

F_simple = F.simplify_full()
F_simple
# Out:
# 0

# %%
print(F_simple)
# Out:
# 0

# %%
G = X_v.dot_product(X_v)
G

G_simple = G.simplify_full()
G_simple
# Out:
# -16*cos(v)^2*cosh(u)^2 + 16*cosh(u)^4

# %%
print(G_simple)
# Out:
# -16*cos(v)^2*cosh(u)^2 + 16*cosh(u)^4

# %%
cross_catalan = X_u.cross_product(X_v)
cross_catalan

cross_catalan_simple = cross_catalan.simplify_full()
cross_catalan_simple
# Out:
# (16*cos(v)*cosh(u)^3*sin(v)^2 + 16*cos(v)^3*cosh(u)*sinh(u)^2, -16*(cos(v)^2*cosh(u) - cosh(u)^3)*sin(v), -16*cos(v)^2*cosh(u)*sinh(u) + 16*cosh(u)^3*sinh(u))

# %%
print(cross_catalan_simple)
# Out:
# (16*cos(v)*cosh(u)^3*sin(v)^2 + 16*cos(v)^3*cosh(u)*sinh(u)^2, -16*(cos(v)^2*cosh(u) - cosh(u)^3)*sin(v), -16*cos(v)^2*cosh(u)*sinh(u) + 16*cosh(u)^3*sinh(u))

# %%
cross_catalan_norm = cross_catalan.norm(2)
cross_catalan_norm

cross_catalan_norm_simple = cross_catalan_norm.simplify_full()
cross_catalan_norm_simple
# Out:
# 16*sqrt(cos(v)^4*cosh(u)^4 - 2*cos(v)^2*cosh(u)^6 + cosh(u)^8)

# %%
print(cross_catalan_norm_simple)
# Out:
# 16*sqrt(cos(v)^4*cosh(u)^4 - 2*cos(v)^2*cosh(u)^6 + cosh(u)^8)

# %%
N = (cross_catalan)/(cross_catalan_norm)
N

N_simple = N.simplify_full()
N_simple
# Out:
# ((cos(v)*cosh(u)^3*sin(v)^2 + cos(v)^3*cosh(u)*sinh(u)^2)/sqrt(cos(v)^4*cosh(u)^4 - 2*cos(v)^2*cosh(u)^6 + cosh(u)^8), -(cos(v)^2*cosh(u) - cosh(u)^3)*sin(v)/sqrt(cos(v)^4*cosh(u)^4 - 2*cos(v)^2*cosh(u)^6 + cosh(u)^8), -(cos(v)^2*cosh(u)*sinh(u) - cosh(u)^3*sinh(u))/sqrt(cos(v)^4*cosh(u)^4 - 2*cos(v)^2*cosh(u)^6 + cosh(u)^8))

# %%
print(N_simple)
# Out:
# ((cos(v)*cosh(u)^3*sin(v)^2 + cos(v)^3*cosh(u)*sinh(u)^2)/sqrt(cos(v)^4*cosh(u)^4 - 2*cos(v)^2*cosh(u)^6 + cosh(u)^8), -(cos(v)^2*cosh(u) - cosh(u)^3)*sin(v)/sqrt(cos(v)^4*cosh(u)^4 - 2*cos(v)^2*cosh(u)^6 + cosh(u)^8), -(cos(v)^2*cosh(u)*sinh(u) - cosh(u)^3*sinh(u))/sqrt(cos(v)^4*cosh(u)^4 - 2*cos(v)^2*cosh(u)^6 + cosh(u)^8))

# %%
e = N.dot_product(X_uu)
e

e_simple = e.simplify_full()
e_simple
# Out:
# 4*(cos(v)^2*cosh(u)^3 - cosh(u)^5)*sin(v)/sqrt(cos(v)^4*cosh(u)^4 - 2*cos(v)^2*cosh(u)^6 + cosh(u)^8)

# %%
print(e_simple)
# Out:
# 4*(cos(v)^2*cosh(u)^3 - cosh(u)^5)*sin(v)/sqrt(cos(v)^4*cosh(u)^4 - 2*cos(v)^2*cosh(u)^6 + cosh(u)^8)

# %%
f = N.dot_product(X_uv)
f

f_simple = f.simplify_full()
f_simple
# Out:
# 4*(cos(v)^3*cosh(u)^2*sinh(u) - cos(v)*cosh(u)^4*sinh(u))/sqrt(cos(v)^4*cosh(u)^4 - 2*cos(v)^2*cosh(u)^6 + cosh(u)^8)

# %%
print(f_simple)
# Out:
# 4*(cos(v)^3*cosh(u)^2*sinh(u) - cos(v)*cosh(u)^4*sinh(u))/sqrt(cos(v)^4*cosh(u)^4 - 2*cos(v)^2*cosh(u)^6 + cosh(u)^8)

# %%
g = N.dot_product(X_vv)
g

g_simple = g.simplify_full()
g_simple
# Out:
# -4*(cos(v)^2*cosh(u)^3 - cosh(u)^5)*sin(v)/sqrt(cos(v)^4*cosh(u)^4 - 2*cos(v)^2*cosh(u)^6 + cosh(u)^8)

# %%
print(g_simple)
# Out:
# -4*(cos(v)^2*cosh(u)^3 - cosh(u)^5)*sin(v)/sqrt(cos(v)^4*cosh(u)^4 - 2*cos(v)^2*cosh(u)^6 + cosh(u)^8)

# %% [markdown]
# ## Curvatura Gaussiana (K)

# %%
K_catalan = (e*g - f^2)/(E*G - F^2)
K_catalan

K_catalan_simple = K_catalan.simplify_full()
K_catalan_simple
# Out:
# 1/16/(cos(v)^2*cosh(u)^4 - cosh(u)^6)

# %%
print(K_catalan_simple)
# Out:
# 1/16/(cos(v)^2*cosh(u)^4 - cosh(u)^6)

# %% [markdown]
# ## Curvatura Média (H)

# %%
H_catalan = (e*G - 2*f*F + g*E)/(2*(E*G - F^2))
H_catalan

H_catalan_simple = H_catalan.simplify_full()
H_catalan_simple
# Out:
# 0

# %%
print(H_catalan_simple)
# Out:
# 0
