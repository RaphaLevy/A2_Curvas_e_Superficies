# %% [markdown]
# # A2 - Curvas e Superfícies

# %% [markdown]
# ## Alunos: Juliana Carvalho e Raphael Levy

# %%
# %display latex

# %% [markdown]
# ## Helicoide:

# %%
u, v = var('u,v', domain='real')
Helicoide = ParametrizedSurface3D((v*cos(u), v*sin(u), u), (u, v)); Helicoide
parametric_plot3d((v*cos(u), v*sin(u), u), (u,0,3*pi), (v,-pi,pi))
# Out:
# Graphics3d Object

# %%
u, v = var('u, v')
f = v*cos(u)
g = v*sin(u)
h = u

print('f = v*cos(u)')
print('g = v*sin(u)')
print('h = u')

print(' ')
print('-------------------------------------------')
print(' ')

X_u = vector([diff(f, u), diff(g, u), diff(h, u)])
print(f'Primeira derivada (X_u): {X_u}')
print(' ')

X_uu = vector([diff(f, u, 2), diff(g, u, 2), diff(h, u, 2)])
print(f'Segunda derivada (X_uu): {X_uu}')


print(' ')
print('-------------------------------------------')
print(' ')

X_v = vector([diff(f, v), diff(g, v), diff(h, v)])
print(f'Primeira derivada (X_v): {X_v}')
print(' ')

X_vv = vector([diff(f, v, 2), diff(g, v, 2), diff(h, v, 2)])
print(f'Segunda derivada (X_vv): {X_vv}')

print(' ')
print('-------------------------------------------')
print(' ')

X_uv = vector([diff(f, u, v), diff(g, u, v), diff(h, u, v)])
print(f'Segunda derivada (X_uv): {X_uv}')
print(' ')

X_vu = vector([diff(f, v, u), diff(g, v, u), diff(h, v, u)])
print(f'Segunda derivada (X_vu): {X_vu}')
print(' ')
# Out:
# f = v*cos(u)
# g = v*sin(u)
# h = u
#
# -------------------------------------------
#
# Primeira derivada (X_u): (-v*sin(u), v*cos(u), 1)
#
# Segunda derivada (X_uu): (-v*cos(u), -v*sin(u), 0)
#
# -------------------------------------------
#
# Primeira derivada (X_v): (cos(u), sin(u), 0)
#
# Segunda derivada (X_vv): (0, 0, 0)
#
# -------------------------------------------
#
# Segunda derivada (X_uv): (-sin(u), cos(u), 0)
#
# Segunda derivada (X_vu): (-sin(u), cos(u), 0)

# %%
E = X_u.dot_product(X_u)
E
# Out:
# v^2*cos(u)^2 + v^2*sin(u)^2 + 1

# %%
E_simple = E.simplify_full()
E_simple
# Out:
# v^2 + 1

# %%
F = X_u.dot_product(X_v)
F
# Out:
# 0

# %%
G = X_v.dot_product(X_v)
G
# Out:
# cos(u)^2 + sin(u)^2

# %%
G_simple = G.simplify_full()
G_simple
# Out:
# 1

# %%
cross_helic = X_u.cross_product(X_v)
cross_helic
# Out:
# (-sin(u), cos(u), -v*cos(u)^2 - v*sin(u)^2)

# %%
cross_helic_simple = cross_helic.simplify_full()
cross_helic_simple
# Out:
# (-sin(u), cos(u), -v)

# %%
cross_helic_norm = cross_helic.norm(2)
cross_helic_norm
# Out:
# sqrt((v*cos(u)^2 + v*sin(u)^2)^2 + cos(u)^2 + sin(u)^2)

# %%
cross_helic_norm_simple = cross_helic_norm.simplify_full()
cross_helic_norm_simple
# Out:
# sqrt(v^2 + 1)

# %%
N = (cross_helic)/(cross_helic_norm)
N
# Out:
# (-sin(u)/sqrt((v*cos(u)^2 + v*sin(u)^2)^2 + cos(u)^2 + sin(u)^2), cos(u)/sqrt((v*cos(u)^2 + v*sin(u)^2)^2 + cos(u)^2 + sin(u)^2), -(v*cos(u)^2 + v*sin(u)^2)/sqrt((v*cos(u)^2 + v*sin(u)^2)^2 + cos(u)^2 + sin(u)^2))

# %%
N_simple = N.simplify_full()
N_simple
# Out:
# (-sin(u)/sqrt(v^2 + 1), cos(u)/sqrt(v^2 + 1), -v/sqrt(v^2 + 1))

# %%
e = N.dot_product(X_uu)
e
# Out:
# 0

# %%
f = N.dot_product(X_uv)
f
# Out:
# cos(u)^2/sqrt((v*cos(u)^2 + v*sin(u)^2)^2 + cos(u)^2 + sin(u)^2) + sin(u)^2/sqrt((v*cos(u)^2 + v*sin(u)^2)^2 + cos(u)^2 + sin(u)^2)

# %%
f_simple = f.simplify_full()
f_simple
# Out:
# 1/sqrt(v^2 + 1)

# %%
g = N.dot_product(X_vv)
g
# Out:
# 0

# %% [markdown]
# ## Curvatura Gaussiana (k)

# %%
k_helic = (e*g - f^2)/(E*G - F^2)
k_helic
# Out:
# -(cos(u)^2/sqrt((v*cos(u)^2 + v*sin(u)^2)^2 + cos(u)^2 + sin(u)^2) + sin(u)^2/sqrt((v*cos(u)^2 + v*sin(u)^2)^2 + cos(u)^2 + sin(u)^2))^2/((v^2*cos(u)^2 + v^2*sin(u)^2 + 1)*(cos(u)^2 + sin(u)^2))

# %%
k_helic_simple = k_helic.simplify_full()
k_helic_simple
# Out:
# -1/(v^4 + 2*v^2 + 1)

# %% [markdown]
# ## Curvatura Média (H)

# %%
H_helic = (e*G - 2*f*F + g*E)/(2*(E*G - F^2))
H_helic
# Out:
# 0

# %% [markdown]
# ## Catenoide:

# %%
u, v = var('u,v', domain='real')
Catenoide = ParametrizedSurface3D((cos(u)*cosh(v), cosh(v)*sin(u), v), (u, v)); Catenoide
parametric_plot3d((cos(u)*cosh(v), cosh(v)*sin(u), v), (u,0,2*pi), (v,-pi/2,pi/2), color = 'green')
# Out:
# Graphics3d Object

# %%
u, v = var('u, v')
f = cos(u)*cosh(v)
g = cosh(v)*sin(u)
h = v

print('f = cos(u)*cosh(v)')
print('g = cosh(v)*sin(u)')
print('h = v')

print(' ')
print('-------------------------------------------')
print(' ')

X_u = vector([diff(f, u), diff(g, u), diff(h, u)])
print(f'Primeira derivada (X_u): {X_u}')
print(' ')

X_uu = vector([diff(f, u, 2), diff(g, u, 2), diff(h, u, 2)])
print(f'Segunda derivada (X_uu): {X_uu}')


print(' ')
print('-------------------------------------------')
print(' ')

X_v = vector([diff(f, v), diff(g, v), diff(h, v)])
print(f'Primeira derivada (X_v): {X_v}')
print(' ')

X_vv = vector([diff(f, v, 2), diff(g, v, 2), diff(h, v, 2)])
print(f'Segunda derivada (X_vv): {X_vv}')

print(' ')
print('-------------------------------------------')
print(' ')

X_uv = vector([diff(f, u, v), diff(g, u, v), diff(h, u, v)])
print(f'Segunda derivada (X_uv): {X_uv}')
print(' ')

X_vu = vector([diff(f, v, u), diff(g, v, u), diff(h, v, u)])
print(f'Segunda derivada (X_vu): {X_vu}')
print(' ')
# Out:
# f = cos(u)*cosh(v)
# g = cosh(v)*sin(u)
# h = v
#
# -------------------------------------------
#
# Primeira derivada (X_u): (-cosh(v)*sin(u), cos(u)*cosh(v), 0)
#
# Segunda derivada (X_uu): (-cos(u)*cosh(v), -cosh(v)*sin(u), 0)
#
# -------------------------------------------
#
# Primeira derivada (X_v): (cos(u)*sinh(v), sin(u)*sinh(v), 1)
#
# Segunda derivada (X_vv): (cos(u)*cosh(v), cosh(v)*sin(u), 0)
#
# -------------------------------------------
#
# Segunda derivada (X_uv): (-sin(u)*sinh(v), cos(u)*sinh(v), 0)
#
# Segunda derivada (X_vu): (-sin(u)*sinh(v), cos(u)*sinh(v), 0)

# %%
E = X_u.dot_product(X_u)
E
# Out:
# cos(u)^2*cosh(v)^2 + cosh(v)^2*sin(u)^2

# %%
E_simple = E.simplify_full()
E_simple
# Out:
# cosh(v)^2

# %%
F = X_u.dot_product(X_v)
F
# Out:
# 0

# %%
G = X_v.dot_product(X_v)
G
# Out:
# cos(u)^2*sinh(v)^2 + sin(u)^2*sinh(v)^2 + 1

# %%
G_simple = G.simplify_full()
G_simple
# Out:
# cosh(v)^2

# %%
cross_cat = X_u.cross_product(X_v)
cross_cat
# Out:
# (cos(u)*cosh(v), cosh(v)*sin(u), -cos(u)^2*cosh(v)*sinh(v) - cosh(v)*sin(u)^2*sinh(v))

# %%
cross_cat_simple = cross_cat.simplify_full()
cross_cat_simple
# Out:
# (cos(u)*cosh(v), cosh(v)*sin(u), -cosh(v)*sinh(v))

# %%
cross_cat_norm = cross_cat.norm(2)
cross_cat_norm
# Out:
# sqrt(cos(u)^2*cosh(v)^2 + cosh(v)^2*sin(u)^2 + (cos(u)^2*cosh(v)*sinh(v) + cosh(v)*sin(u)^2*sinh(v))^2)

# %%
cross_cat_norm_simple = cross_cat_norm.simplify_full()
cross_cat_norm_simple
# Out:
# cosh(v)^2

# %%
N = (cross_cat)/(cross_cat_norm)
N
# Out:
# (cos(u)*cosh(v)/sqrt(cos(u)^2*cosh(v)^2 + cosh(v)^2*sin(u)^2 + (cos(u)^2*cosh(v)*sinh(v) + cosh(v)*sin(u)^2*sinh(v))^2), cosh(v)*sin(u)/sqrt(cos(u)^2*cosh(v)^2 + cosh(v)^2*sin(u)^2 + (cos(u)^2*cosh(v)*sinh(v) + cosh(v)*sin(u)^2*sinh(v))^2), -(cos(u)^2*cosh(v)*sinh(v) + cosh(v)*sin(u)^2*sinh(v))/sqrt(cos(u)^2*cosh(v)^2 + cosh(v)^2*sin(u)^2 + (cos(u)^2*cosh(v)*sinh(v) + cosh(v)*sin(u)^2*sinh(v))^2))

# %%
N_simple = N.simplify_full()
N_simple
# Out:
# (cos(u)/cosh(v), sin(u)/cosh(v), -sinh(v)/cosh(v))

# %%
e = N.dot_product(X_uu)
e
# Out:
# -cos(u)^2*cosh(v)^2/sqrt(cos(u)^2*cosh(v)^2 + cosh(v)^2*sin(u)^2 + (cos(u)^2*cosh(v)*sinh(v) + cosh(v)*sin(u)^2*sinh(v))^2) - cosh(v)^2*sin(u)^2/sqrt(cos(u)^2*cosh(v)^2 + cosh(v)^2*sin(u)^2 + (cos(u)^2*cosh(v)*sinh(v) + cosh(v)*sin(u)^2*sinh(v))^2)

# %%
e_simple = e.simplify_full()
e_simple
# Out:
# -1

# %%
f = N.dot_product(X_uv)
f
# Out:
# 0

# %%
g = N.dot_product(X_vv)
g
# Out:
# cos(u)^2*cosh(v)^2/sqrt(cos(u)^2*cosh(v)^2 + cosh(v)^2*sin(u)^2 + (cos(u)^2*cosh(v)*sinh(v) + cosh(v)*sin(u)^2*sinh(v))^2) + cosh(v)^2*sin(u)^2/sqrt(cos(u)^2*cosh(v)^2 + cosh(v)^2*sin(u)^2 + (cos(u)^2*cosh(v)*sinh(v) + cosh(v)*sin(u)^2*sinh(v))^2)

# %%
g_simple = g.simplify_full()
g_simple
# Out:
# 1

# %% [markdown]
# ## Curvatura Gaussiana (k)

# %%
k_cat = (e*g - f^2)/(E*G - F^2)
k_cat
# Out:
# -(cos(u)^2*cosh(v)^2/sqrt(cos(u)^2*cosh(v)^2 + cosh(v)^2*sin(u)^2 + (cos(u)^2*cosh(v)*sinh(v) + cosh(v)*sin(u)^2*sinh(v))^2) + cosh(v)^2*sin(u)^2/sqrt(cos(u)^2*cosh(v)^2 + cosh(v)^2*sin(u)^2 + (cos(u)^2*cosh(v)*sinh(v) + cosh(v)*sin(u)^2*sinh(v))^2))^2/((cos(u)^2*cosh(v)^2 + cosh(v)^2*sin(u)^2)*(cos(u)^2*sinh(v)^2 + sin(u)^2*sinh(v)^2 + 1))

# %%
k_cat_simple = k_cat.simplify_full()
k_cat_simple
# Out:
# -1/cosh(v)^4

# %% [markdown]
# ## Curvatura Média (H)

# %%
H_cat = (e*G - 2*f*F + g*E)/(2*(E*G - F^2))
H_cat
# Out:
# 1/2*((cos(u)^2*cosh(v)^2 + cosh(v)^2*sin(u)^2)*(cos(u)^2*cosh(v)^2/sqrt(cos(u)^2*cosh(v)^2 + cosh(v)^2*sin(u)^2 + (cos(u)^2*cosh(v)*sinh(v) + cosh(v)*sin(u)^2*sinh(v))^2) + cosh(v)^2*sin(u)^2/sqrt(cos(u)^2*cosh(v)^2 + cosh(v)^2*sin(u)^2 + (cos(u)^2*cosh(v)*sinh(v) + cosh(v)*sin(u)^2*sinh(v))^2)) - (cos(u)^2*sinh(v)^2 + sin(u)^2*sinh(v)^2 + 1)*(cos(u)^2*cosh(v)^2/sqrt(cos(u)^2*cosh(v)^2 + cosh(v)^2*sin(u)^2 + (cos(u)^2*cosh(v)*sinh(v) + cosh(v)*sin(u)^2*sinh(v))^2) + cosh(v)^2*sin(u)^2/sqrt(cos(u)^2*cosh(v)^2 + cosh(v)^2*sin(u)^2 + (cos(u)^2*cosh(v)*sinh(v) + cosh(v)*sin(u)^2*sinh(v))^2)))/((cos(u)^2*cosh(v)^2 + cosh(v)^2*sin(u)^2)*(cos(u)^2*sinh(v)^2 + sin(u)^2*sinh(v)^2 + 1))

# %%
H_cat_simple = H_cat.simplify_full()
H_cat_simple
# Out:
# 0

# %% [markdown]
# ## Esfera:

# %%
u, v = var('u,v', domain='real')
Esfera = ParametrizedSurface3D((sin(u)*cos(v), sin(u)*sin(v), cos(u)), (u, v)); Esfera
parametric_plot3d((sin(u)*cos(v), sin(u)*sin(v), cos(u)), (u,0,pi), (v,0, 2*pi), color = 'purple')
# Out:
# Graphics3d Object

# %%
u, v = var('u, v')
f = sin(u)*cos(v)
g = sin(u)*sin(v)
h = cos(u)

print('f = sin(u)*cos(v)')
print('g = sin(u)*sin(v)')
print('h = cos(u)')

print(' ')
print('-------------------------------------------')
print(' ')

X_u = vector([diff(f, u), diff(g, u), diff(h, u)])
print(f'Primeira derivada (X_u): {X_u}')
print(' ')

X_uu = vector([diff(f, u, 2), diff(g, u, 2), diff(h, u, 2)])
print(f'Segunda derivada (X_uu): {X_uu}')


print(' ')
print('-------------------------------------------')
print(' ')

X_v = vector([diff(f, v), diff(g, v), diff(h, v)])
print(f'Primeira derivada (X_v): {X_v}')
print(' ')

X_vv = vector([diff(f, v, 2), diff(g, v, 2), diff(h, v, 2)])
print(f'Segunda derivada (X_vv): {X_vv}')

print(' ')
print('-------------------------------------------')
print(' ')

X_uv = vector([diff(f, u, v), diff(g, u, v), diff(h, u, v)])
print(f'Segunda derivada (X_uv): {X_uv}')
print(' ')

X_vu = vector([diff(f, v, u), diff(g, v, u), diff(h, v, u)])
print(f'Segunda derivada (X_vu): {X_vu}')
print(' ')
# Out:
# f = sin(u)*cos(v)
# g = sin(u)*sin(v)
# h = cos(u)
#
# -------------------------------------------
#
# Primeira derivada (X_u): (cos(u)*cos(v), cos(u)*sin(v), -sin(u))
#
# Segunda derivada (X_uu): (-cos(v)*sin(u), -sin(u)*sin(v), -cos(u))
#
# -------------------------------------------
#
# Primeira derivada (X_v): (-sin(u)*sin(v), cos(v)*sin(u), 0)
#
# Segunda derivada (X_vv): (-cos(v)*sin(u), -sin(u)*sin(v), 0)
#
# -------------------------------------------
#
# Segunda derivada (X_uv): (-cos(u)*sin(v), cos(u)*cos(v), 0)
#
# Segunda derivada (X_vu): (-cos(u)*sin(v), cos(u)*cos(v), 0)

# %%
E = X_u.dot_product(X_u)
E
# Out:
# cos(u)^2*cos(v)^2 + cos(u)^2*sin(v)^2 + sin(u)^2

# %%
E_simple = E.simplify_full()
E_simple
# Out:
# 1

# %%
F = X_u.dot_product(X_v)
F
# Out:
# 0

# %%
G = X_v.dot_product(X_v)
G
# Out:
# cos(v)^2*sin(u)^2 + sin(u)^2*sin(v)^2

# %%
G_simple = G.simplify_full()
G_simple
# Out:
# sin(u)^2

# %%
cross_esf = X_u.cross_product(X_v)
cross_esf
# Out:
# (cos(v)*sin(u)^2, sin(u)^2*sin(v), cos(u)*cos(v)^2*sin(u) + cos(u)*sin(u)*sin(v)^2)

# %%
cross_esf_simple = cross_esf.simplify_full()
cross_esf_simple
# Out:
# (cos(v)*sin(u)^2, sin(u)^2*sin(v), cos(u)*sin(u))

# %%
cross_esf_norm = cross_esf.norm(2)
cross_esf_norm
# Out:
# sqrt(cos(v)^2*sin(u)^4 + sin(u)^4*sin(v)^2 + (cos(u)*cos(v)^2*sin(u) + cos(u)*sin(u)*sin(v)^2)^2)

# %%
cross_esf_norm_simple = cross_esf_norm.simplify_full()
cross_esf_norm_simple
# Out:
# abs(sin(u))

# %%
N = (cross_esf)/(cross_esf_norm)
N
# Out:
# (cos(v)*sin(u)^2/sqrt(cos(v)^2*sin(u)^4 + sin(u)^4*sin(v)^2 + (cos(u)*cos(v)^2*sin(u) + cos(u)*sin(u)*sin(v)^2)^2), sin(u)^2*sin(v)/sqrt(cos(v)^2*sin(u)^4 + sin(u)^4*sin(v)^2 + (cos(u)*cos(v)^2*sin(u) + cos(u)*sin(u)*sin(v)^2)^2), (cos(u)*cos(v)^2*sin(u) + cos(u)*sin(u)*sin(v)^2)/sqrt(cos(v)^2*sin(u)^4 + sin(u)^4*sin(v)^2 + (cos(u)*cos(v)^2*sin(u) + cos(u)*sin(u)*sin(v)^2)^2))

# %%
N_simple = N.simplify_full()
N_simple
# Out:
# (abs(sin(u))*cos(v), abs(sin(u))*sin(v), cos(u)*sin(u)/abs(sin(u)))

# %%
e = N.dot_product(X_uu)
e
# Out:
# -cos(v)^2*sin(u)^3/sqrt(cos(v)^2*sin(u)^4 + sin(u)^4*sin(v)^2 + (cos(u)*cos(v)^2*sin(u) + cos(u)*sin(u)*sin(v)^2)^2) - sin(u)^3*sin(v)^2/sqrt(cos(v)^2*sin(u)^4 + sin(u)^4*sin(v)^2 + (cos(u)*cos(v)^2*sin(u) + cos(u)*sin(u)*sin(v)^2)^2) - (cos(u)*cos(v)^2*sin(u) + cos(u)*sin(u)*sin(v)^2)*cos(u)/sqrt(cos(v)^2*sin(u)^4 + sin(u)^4*sin(v)^2 + (cos(u)*cos(v)^2*sin(u) + cos(u)*sin(u)*sin(v)^2)^2)

# %%
e_simple = e.simplify_full()
e_simple
# Out:
# -sin(u)/abs(sin(u))

# %%
f = N.dot_product(X_uv)
f
# Out:
# 0

# %%
g = N.dot_product(X_vv)
g
# Out:
# -cos(v)^2*sin(u)^3/sqrt(cos(v)^2*sin(u)^4 + sin(u)^4*sin(v)^2 + (cos(u)*cos(v)^2*sin(u) + cos(u)*sin(u)*sin(v)^2)^2) - sin(u)^3*sin(v)^2/sqrt(cos(v)^2*sin(u)^4 + sin(u)^4*sin(v)^2 + (cos(u)*cos(v)^2*sin(u) + cos(u)*sin(u)*sin(v)^2)^2)

# %%
g_simple = g.simplify_full()
g_simple
# Out:
# -abs(sin(u))*sin(u)

# %% [markdown]
# ## Curvatura Gaussiana (k)

# %%
k_esf = (e*g - f^2)/(E*G - F^2)
k_esf
# Out:
# (cos(v)^2*sin(u)^3/sqrt(cos(v)^2*sin(u)^4 + sin(u)^4*sin(v)^2 + (cos(u)*cos(v)^2*sin(u) + cos(u)*sin(u)*sin(v)^2)^2) + sin(u)^3*sin(v)^2/sqrt(cos(v)^2*sin(u)^4 + sin(u)^4*sin(v)^2 + (cos(u)*cos(v)^2*sin(u) + cos(u)*sin(u)*sin(v)^2)^2) + (cos(u)*cos(v)^2*sin(u) + cos(u)*sin(u)*sin(v)^2)*cos(u)/sqrt(cos(v)^2*sin(u)^4 + sin(u)^4*sin(v)^2 + (cos(u)*cos(v)^2*sin(u) + cos(u)*sin(u)*sin(v)^2)^2))*(cos(v)^2*sin(u)^3/sqrt(cos(v)^2*sin(u)^4 + sin(u)^4*sin(v)^2 + (cos(u)*cos(v)^2*sin(u) + cos(u)*sin(u)*sin(v)^2)^2) + sin(u)^3*sin(v)^2/sqrt(cos(v)^2*sin(u)^4 + sin(u)^4*sin(v)^2 + (cos(u)*cos(v)^2*sin(u) + cos(u)*sin(u)*sin(v)^2)^2))/((cos(u)^2*cos(v)^2 + cos(u)^2*sin(v)^2 + sin(u)^2)*(cos(v)^2*sin(u)^2 + sin(u)^2*sin(v)^2))

# %%
k_esf_simple = k_esf.simplify_full()
k_esf_simple
# Out:
# 1

# %% [markdown]
# ## Curvatura Média (H)

# %%
H_esf = (e*G - 2*f*F + g*E)/(2*(E*G - F^2))
H_esf
# Out:
# -1/2*((cos(v)^2*sin(u)^3/sqrt(cos(v)^2*sin(u)^4 + sin(u)^4*sin(v)^2 + (cos(u)*cos(v)^2*sin(u) + cos(u)*sin(u)*sin(v)^2)^2) + sin(u)^3*sin(v)^2/sqrt(cos(v)^2*sin(u)^4 + sin(u)^4*sin(v)^2 + (cos(u)*cos(v)^2*sin(u) + cos(u)*sin(u)*sin(v)^2)^2))*(cos(u)^2*cos(v)^2 + cos(u)^2*sin(v)^2 + sin(u)^2) + (cos(v)^2*sin(u)^3/sqrt(cos(v)^2*sin(u)^4 + sin(u)^4*sin(v)^2 + (cos(u)*cos(v)^2*sin(u) + cos(u)*sin(u)*sin(v)^2)^2) + sin(u)^3*sin(v)^2/sqrt(cos(v)^2*sin(u)^4 + sin(u)^4*sin(v)^2 + (cos(u)*cos(v)^2*sin(u) + cos(u)*sin(u)*sin(v)^2)^2) + (cos(u)*cos(v)^2*sin(u) + cos(u)*sin(u)*sin(v)^2)*cos(u)/sqrt(cos(v)^2*sin(u)^4 + sin(u)^4*sin(v)^2 + (cos(u)*cos(v)^2*sin(u) + cos(u)*sin(u)*sin(v)^2)^2))*(cos(v)^2*sin(u)^2 + sin(u)^2*sin(v)^2))/((cos(u)^2*cos(v)^2 + cos(u)^2*sin(v)^2 + sin(u)^2)*(cos(v)^2*sin(u)^2 + sin(u)^2*sin(v)^2))

# %%
H_esf_simple = H_esf.simplify_full()
H_esf_simple
# Out:
# -sin(u)/abs(sin(u))

# %% [markdown]
# ## Coruja de Maeder:

# %%
u, v = var('u,v', domain='real')
f = v*cos(u) - (1/2)*(v^2)*cos(2*u)
g = -v*sin(u) - (1/2)*(v^2)*sin(2*u)
h = (4/3)*(v^(3/2))*cos(3/2*u)
Maeder = ParametrizedSurface3D((f, g, h), (u, v)); Maeder
parametric_plot3d((f, g, h), (u,0, 4*pi), (v,0,1), color = 'orange')
# Out:
# Graphics3d Object

# %%
u, v = var('u, v')
f = v*cos(u) - (1/2)*(v^2)*cos(2*u)
g = -v*sin(u) - (1/2)*(v^2)*sin(2*u)
h = (4/3)*(v^(3/2))*cos(3/2*u)

print('f = v*cos(u) - (1/2)*(v^2)*cos(2*u)')
print('g = -v*sin(u) - (1/2)*(v^2)*sin(2*u)')
print('h = (4/3)*(v^(3/2))*cos(3/2*u)')

print(' ')
print('-------------------------------------------')
print(' ')

X_u = vector([diff(f, u), diff(g, u), diff(h, u)])
print(f'Primeira derivada (X_u): {X_u}')
print(' ')

X_uu = vector([diff(f, u, 2), diff(g, u, 2), diff(h, u, 2)])
print(f'Segunda derivada (X_uu): {X_uu}')


print(' ')
print('-------------------------------------------')
print(' ')

X_v = vector([diff(f, v), diff(g, v), diff(h, v)])
print(f'Primeira derivada (X_v): {X_v}')
print(' ')

X_vv = vector([diff(f, v, 2), diff(g, v, 2), diff(h, v, 2)])
print(f'Segunda derivada (X_vv): {X_vv}')

print(' ')
print('-------------------------------------------')
print(' ')

X_uv = vector([diff(f, u, v), diff(g, u, v), diff(h, u, v)])
print(f'Segunda derivada (X_uv): {X_uv}')
print(' ')

X_vu = vector([diff(f, v, u), diff(g, v, u), diff(h, v, u)])
print(f'Segunda derivada (X_vu): {X_vu}')
print(' ')
# Out:
# f = v*cos(u) - (1/2)*(v^2)*cos(2*u)
# g = -v*sin(u) - (1/2)*(v^2)*sin(2*u)
# h = (4/3)*(v^(3/2))*cos(3/2*u)
#
# -------------------------------------------
#
# Primeira derivada (X_u): (v^2*sin(2*u) - v*sin(u), -v^2*cos(2*u) - v*cos(u), -2*v^(3/2)*sin(3/2*u))
#
# Segunda derivada (X_uu): (2*v^2*cos(2*u) - v*cos(u), 2*v^2*sin(2*u) + v*sin(u), -3*v^(3/2)*cos(3/2*u))
#
# -------------------------------------------
#
# Primeira derivada (X_v): (-v*cos(2*u) + cos(u), -v*sin(2*u) - sin(u), 2*sqrt(v)*cos(3/2*u))
#
# Segunda derivada (X_vv): (-cos(2*u), -sin(2*u), cos(3/2*u)/sqrt(v))
#
# -------------------------------------------
#
# Segunda derivada (X_uv): (2*v*sin(2*u) - sin(u), -2*v*cos(2*u) - cos(u), -3*sqrt(v)*sin(3/2*u))
#
# Segunda derivada (X_vu): (2*v*sin(2*u) - sin(u), -2*v*cos(2*u) - cos(u), -3*sqrt(v)*sin(3/2*u))

# %%
E = X_u.dot_product(X_u)
E
# Out:
# 4*v^3*sin(3/2*u)^2 + (v^2*cos(2*u) + v*cos(u))^2 + (v^2*sin(2*u) - v*sin(u))^2

# %%
E_simple = E.simplify_full()
E_simple
# Out:
# 2*(4*cos(u)^3 + 2*sin(3/2*u)^2 - 3*cos(u))*v^3 + v^4 + v^2

# %%
F = X_u.dot_product(X_v)
F
# Out:
# -4*v^2*cos(3/2*u)*sin(3/2*u) - (v^2*sin(2*u) - v*sin(u))*(v*cos(2*u) - cos(u)) + (v^2*cos(2*u) + v*cos(u))*(v*sin(2*u) + sin(u))

# %%
F_simple = F.simplify_full()
F_simple
# Out:
# -2*(2*cos(3/2*u)*sin(3/2*u) - (4*cos(u)^2 - 1)*sin(u))*v^2

# %%
G = X_v.dot_product(X_v)
G
# Out:
# 4*v*cos(3/2*u)^2 + (v*cos(2*u) - cos(u))^2 + (v*sin(2*u) + sin(u))^2

# %%
G_simple = G.simplify_full()
G_simple
# Out:
# -2*(4*cos(u)^3 - 2*cos(3/2*u)^2 - 3*cos(u))*v + v^2 + 1

# %%
cross_maeder = X_u.cross_product(X_v)
cross_maeder
# Out:
# (-2*(v*sin(2*u) + sin(u))*v^(3/2)*sin(3/2*u) - 2*(v^2*cos(2*u) + v*cos(u))*sqrt(v)*cos(3/2*u), 2*(v*cos(2*u) - cos(u))*v^(3/2)*sin(3/2*u) - 2*(v^2*sin(2*u) - v*sin(u))*sqrt(v)*cos(3/2*u), -(v^2*cos(2*u) + v*cos(u))*(v*cos(2*u) - cos(u)) - (v^2*sin(2*u) - v*sin(u))*(v*sin(2*u) + sin(u)))

# %%
cross_maeder_simple = cross_maeder.simplify_full()
cross_maeder_simple
# Out:
# (-2*((2*cos(u)*sin(3/2*u)*sin(u) - (2*sin(u)^2 - 1)*cos(3/2*u))*v^2 + (cos(3/2*u)*cos(u) + sin(3/2*u)*sin(u))*v)*sqrt(v), -2*((2*cos(3/2*u)*cos(u)*sin(u) - (2*cos(u)^2 - 1)*sin(3/2*u))*v^2 + (cos(u)*sin(3/2*u) - cos(3/2*u)*sin(u))*v)*sqrt(v), -v^3 + v)

# %%
cross_maeder_norm = cross_maeder.norm(2)
cross_maeder_norm
# Out:
# sqrt(((v^2*cos(2*u) + v*cos(u))*(v*cos(2*u) - cos(u)) + (v^2*sin(2*u) - v*sin(u))*(v*sin(2*u) + sin(u)))^2 + abs(2*(v*cos(2*u) - cos(u))*v^(3/2)*sin(3/2*u) - 2*(v^2*sin(2*u) - v*sin(u))*sqrt(v)*cos(3/2*u))^2 + abs(-2*(v*sin(2*u) + sin(u))*v^(3/2)*sin(3/2*u) - 2*(v^2*cos(2*u) + v*cos(u))*sqrt(v)*cos(3/2*u))^2)

# %%
cross_maeder_norm_simple = cross_maeder_norm.simplify_full()
cross_maeder_norm_simple
# Out:
# sqrt(v^6 + 2*(8*(4*cos(u)^2 - 1)*cos(3/2*u)*sin(3/2*u)*sin(u) + 16*cos(u)^3 - 8*(4*cos(u)^3 - 3*cos(u))*sin(3/2*u)^2 - 12*cos(u) - 1)*v^4 + 4*v^5 + 4*v^3 + v^2)

# %%
N = (cross_maeder)/(cross_maeder_norm)
N
# Out:
# (-2*((v*sin(2*u) + sin(u))*v^(3/2)*sin(3/2*u) + (v^2*cos(2*u) + v*cos(u))*sqrt(v)*cos(3/2*u))/sqrt(((v^2*cos(2*u) + v*cos(u))*(v*cos(2*u) - cos(u)) + (v^2*sin(2*u) - v*sin(u))*(v*sin(2*u) + sin(u)))^2 + abs(2*(v*cos(2*u) - cos(u))*v^(3/2)*sin(3/2*u) - 2*(v^2*sin(2*u) - v*sin(u))*sqrt(v)*cos(3/2*u))^2 + abs(-2*(v*sin(2*u) + sin(u))*v^(3/2)*sin(3/2*u) - 2*(v^2*cos(2*u) + v*cos(u))*sqrt(v)*cos(3/2*u))^2), 2*((v*cos(2*u) - cos(u))*v^(3/2)*sin(3/2*u) - (v^2*sin(2*u) - v*sin(u))*sqrt(v)*cos(3/2*u))/sqrt(((v^2*cos(2*u) + v*cos(u))*(v*cos(2*u) - cos(u)) + (v^2*sin(2*u) - v*sin(u))*(v*sin(2*u) + sin(u)))^2 + abs(2*(v*cos(2*u) - cos(u))*v^(3/2)*sin(3/2*u) - 2*(v^2*sin(2*u) - v*sin(u))*sqrt(v)*cos(3/2*u))^2 + abs(-2*(v*sin(2*u) + sin(u))*v^(3/2)*sin(3/2*u) - 2*(v^2*cos(2*u) + v*cos(u))*sqrt(v)*cos(3/2*u))^2), -((v^2*cos(2*u) + v*cos(u))*(v*cos(2*u) - cos(u)) + (v^2*sin(2*u) - v*sin(u))*(v*sin(2*u) + sin(u)))/sqrt(((v^2*cos(2*u) + v*cos(u))*(v*cos(2*u) - cos(u)) + (v^2*sin(2*u) - v*sin(u))*(v*sin(2*u) + sin(u)))^2 + abs(2*(v*cos(2*u) - cos(u))*v^(3/2)*sin(3/2*u) - 2*(v^2*sin(2*u) - v*sin(u))*sqrt(v)*cos(3/2*u))^2 + abs(-2*(v*sin(2*u) + sin(u))*v^(3/2)*sin(3/2*u) - 2*(v^2*cos(2*u) + v*cos(u))*sqrt(v)*cos(3/2*u))^2))

# %%
N_simple = N.simplify_full()
N_simple
# Out:
# (-2*((2*cos(u)*sin(3/2*u)*sin(u) - (2*sin(u)^2 - 1)*cos(3/2*u))*v^2 + (cos(3/2*u)*cos(u) + sin(3/2*u)*sin(u))*v)*sqrt(v)/sqrt(v^6 + 2*(8*(4*cos(u)^2 - 1)*cos(3/2*u)*sin(3/2*u)*sin(u) + 16*cos(u)^3 - 8*(4*cos(u)^3 - 3*cos(u))*sin(3/2*u)^2 - 12*cos(u) - 1)*v^4 + 4*v^5 + 4*v^3 + v^2), -2*((2*cos(3/2*u)*cos(u)*sin(u) - (2*cos(u)^2 - 1)*sin(3/2*u))*v^2 + (cos(u)*sin(3/2*u) - cos(3/2*u)*sin(u))*v)*sqrt(v)/sqrt(v^6 + 2*(8*(4*cos(u)^2 - 1)*cos(3/2*u)*sin(3/2*u)*sin(u) + 16*cos(u)^3 - 8*(4*cos(u)^3 - 3*cos(u))*sin(3/2*u)^2 - 12*cos(u) - 1)*v^4 + 4*v^5 + 4*v^3 + v^2), -(v^3 - v)/sqrt(v^6 + 2*(8*(4*cos(u)^2 - 1)*cos(3/2*u)*sin(3/2*u)*sin(u) + 16*cos(u)^3 - 8*(4*cos(u)^3 - 3*cos(u))*sin(3/2*u)^2 - 12*cos(u) - 1)*v^4 + 4*v^5 + 4*v^3 + v^2))

# %%
e = N.dot_product(X_uu)
e
# Out:
# 3*((v^2*cos(2*u) + v*cos(u))*(v*cos(2*u) - cos(u)) + (v^2*sin(2*u) - v*sin(u))*(v*sin(2*u) + sin(u)))*v^(3/2)*cos(3/2*u)/sqrt(((v^2*cos(2*u) + v*cos(u))*(v*cos(2*u) - cos(u)) + (v^2*sin(2*u) - v*sin(u))*(v*sin(2*u) + sin(u)))^2 + abs(2*(v*cos(2*u) - cos(u))*v^(3/2)*sin(3/2*u) - 2*(v^2*sin(2*u) - v*sin(u))*sqrt(v)*cos(3/2*u))^2 + abs(-2*(v*sin(2*u) + sin(u))*v^(3/2)*sin(3/2*u) - 2*(v^2*cos(2*u) + v*cos(u))*sqrt(v)*cos(3/2*u))^2) - 2*((v*sin(2*u) + sin(u))*v^(3/2)*sin(3/2*u) + (v^2*cos(2*u) + v*cos(u))*sqrt(v)*cos(3/2*u))*(2*v^2*cos(2*u) - v*cos(u))/sqrt(((v^2*cos(2*u) + v*cos(u))*(v*cos(2*u) - cos(u)) + (v^2*sin(2*u) - v*sin(u))*(v*sin(2*u) + sin(u)))^2 + abs(2*(v*cos(2*u) - cos(u))*v^(3/2)*sin(3/2*u) - 2*(v^2*sin(2*u) - v*sin(u))*sqrt(v)*cos(3/2*u))^2 + abs(-2*(v*sin(2*u) + sin(u))*v^(3/2)*sin(3/2*u) - 2*(v^2*cos(2*u) + v*cos(u))*sqrt(v)*cos(3/2*u))^2) + 2*((v*cos(2*u) - cos(u))*v^(3/2)*sin(3/2*u) - (v^2*sin(2*u) - v*sin(u))*sqrt(v)*cos(3/2*u))*(2*v^2*sin(2*u) + v*sin(u))/sqrt(((v^2*cos(2*u) + v*cos(u))*(v*cos(2*u) - cos(u)) + (v^2*sin(2*u) - v*sin(u))*(v*sin(2*u) + sin(u)))^2 + abs(2*(v*cos(2*u) - cos(u))*v^(3/2)*sin(3/2*u) - 2*(v^2*sin(2*u) - v*sin(u))*sqrt(v)*cos(3/2*u))^2 + abs(-2*(v*sin(2*u) + sin(u))*v^(3/2)*sin(3/2*u) - 2*(v^2*cos(2*u) + v*cos(u))*sqrt(v)*cos(3/2*u))^2)

# %%
e_simple = e.simplify_full()
e_simple
# Out:
# -(v^4*cos(3/2*u) + 2*((4*cos(u)^2 - 1)*sin(3/2*u)*sin(u) + (4*cos(u)^3 - 3*cos(u))*cos(3/2*u))*v^3 + v^2*cos(3/2*u))*sqrt(v)/sqrt(v^6 + 2*(8*(4*cos(u)^2 - 1)*cos(3/2*u)*sin(3/2*u)*sin(u) + 16*cos(u)^3 - 8*(4*cos(u)^3 - 3*cos(u))*sin(3/2*u)^2 - 12*cos(u) - 1)*v^4 + 4*v^5 + 4*v^3 + v^2)

# %%
f = N.dot_product(X_uv)
f
# Out:
# 3*((v^2*cos(2*u) + v*cos(u))*(v*cos(2*u) - cos(u)) + (v^2*sin(2*u) - v*sin(u))*(v*sin(2*u) + sin(u)))*sqrt(v)*sin(3/2*u)/sqrt(((v^2*cos(2*u) + v*cos(u))*(v*cos(2*u) - cos(u)) + (v^2*sin(2*u) - v*sin(u))*(v*sin(2*u) + sin(u)))^2 + abs(2*(v*cos(2*u) - cos(u))*v^(3/2)*sin(3/2*u) - 2*(v^2*sin(2*u) - v*sin(u))*sqrt(v)*cos(3/2*u))^2 + abs(-2*(v*sin(2*u) + sin(u))*v^(3/2)*sin(3/2*u) - 2*(v^2*cos(2*u) + v*cos(u))*sqrt(v)*cos(3/2*u))^2) - 2*((v*cos(2*u) - cos(u))*v^(3/2)*sin(3/2*u) - (v^2*sin(2*u) - v*sin(u))*sqrt(v)*cos(3/2*u))*(2*v*cos(2*u) + cos(u))/sqrt(((v^2*cos(2*u) + v*cos(u))*(v*cos(2*u) - cos(u)) + (v^2*sin(2*u) - v*sin(u))*(v*sin(2*u) + sin(u)))^2 + abs(2*(v*cos(2*u) - cos(u))*v^(3/2)*sin(3/2*u) - 2*(v^2*sin(2*u) - v*sin(u))*sqrt(v)*cos(3/2*u))^2 + abs(-2*(v*sin(2*u) + sin(u))*v^(3/2)*sin(3/2*u) - 2*(v^2*cos(2*u) + v*cos(u))*sqrt(v)*cos(3/2*u))^2) - 2*((v*sin(2*u) + sin(u))*v^(3/2)*sin(3/2*u) + (v^2*cos(2*u) + v*cos(u))*sqrt(v)*cos(3/2*u))*(2*v*sin(2*u) - sin(u))/sqrt(((v^2*cos(2*u) + v*cos(u))*(v*cos(2*u) - cos(u)) + (v^2*sin(2*u) - v*sin(u))*(v*sin(2*u) + sin(u)))^2 + abs(2*(v*cos(2*u) - cos(u))*v^(3/2)*sin(3/2*u) - 2*(v^2*sin(2*u) - v*sin(u))*sqrt(v)*cos(3/2*u))^2 + abs(-2*(v*sin(2*u) + sin(u))*v^(3/2)*sin(3/2*u) - 2*(v^2*cos(2*u) + v*cos(u))*sqrt(v)*cos(3/2*u))^2)

# %%
f_simple = f.simplify_full()
f_simple
# Out:
# -(v^3*sin(3/2*u) + 2*((4*cos(u)^2 - 1)*cos(3/2*u)*sin(u) - (4*cos(u)^3 - 3*cos(u))*sin(3/2*u))*v^2 + v*sin(3/2*u))*sqrt(v)/sqrt(v^6 + 2*(8*(4*cos(u)^2 - 1)*cos(3/2*u)*sin(3/2*u)*sin(u) + 16*cos(u)^3 - 8*(4*cos(u)^3 - 3*cos(u))*sin(3/2*u)^2 - 12*cos(u) - 1)*v^4 + 4*v^5 + 4*v^3 + v^2)

# %%
g = N.dot_product(X_vv)
g
# Out:
# 2*((v*sin(2*u) + sin(u))*v^(3/2)*sin(3/2*u) + (v^2*cos(2*u) + v*cos(u))*sqrt(v)*cos(3/2*u))*cos(2*u)/sqrt(((v^2*cos(2*u) + v*cos(u))*(v*cos(2*u) - cos(u)) + (v^2*sin(2*u) - v*sin(u))*(v*sin(2*u) + sin(u)))^2 + abs(2*(v*cos(2*u) - cos(u))*v^(3/2)*sin(3/2*u) - 2*(v^2*sin(2*u) - v*sin(u))*sqrt(v)*cos(3/2*u))^2 + abs(-2*(v*sin(2*u) + sin(u))*v^(3/2)*sin(3/2*u) - 2*(v^2*cos(2*u) + v*cos(u))*sqrt(v)*cos(3/2*u))^2) - 2*((v*cos(2*u) - cos(u))*v^(3/2)*sin(3/2*u) - (v^2*sin(2*u) - v*sin(u))*sqrt(v)*cos(3/2*u))*sin(2*u)/sqrt(((v^2*cos(2*u) + v*cos(u))*(v*cos(2*u) - cos(u)) + (v^2*sin(2*u) - v*sin(u))*(v*sin(2*u) + sin(u)))^2 + abs(2*(v*cos(2*u) - cos(u))*v^(3/2)*sin(3/2*u) - 2*(v^2*sin(2*u) - v*sin(u))*sqrt(v)*cos(3/2*u))^2 + abs(-2*(v*sin(2*u) + sin(u))*v^(3/2)*sin(3/2*u) - 2*(v^2*cos(2*u) + v*cos(u))*sqrt(v)*cos(3/2*u))^2) - ((v^2*cos(2*u) + v*cos(u))*(v*cos(2*u) - cos(u)) + (v^2*sin(2*u) - v*sin(u))*(v*sin(2*u) + sin(u)))*cos(3/2*u)/(sqrt(((v^2*cos(2*u) + v*cos(u))*(v*cos(2*u) - cos(u)) + (v^2*sin(2*u) - v*sin(u))*(v*sin(2*u) + sin(u)))^2 + abs(2*(v*cos(2*u) - cos(u))*v^(3/2)*sin(3/2*u) - 2*(v^2*sin(2*u) - v*sin(u))*sqrt(v)*cos(3/2*u))^2 + abs(-2*(v*sin(2*u) + sin(u))*v^(3/2)*sin(3/2*u) - 2*(v^2*cos(2*u) + v*cos(u))*sqrt(v)*cos(3/2*u))^2)*sqrt(v))

# %%
g_simple = g.simplify_full()
g_simple
# Out:
# (v^3*cos(3/2*u) + 2*((4*cos(u)^2 - 1)*sin(3/2*u)*sin(u) + (4*cos(u)^3 - 3*cos(u))*cos(3/2*u))*v^2 + v*cos(3/2*u))/(sqrt(v^6 + 2*(8*(4*cos(u)^2 - 1)*cos(3/2*u)*sin(3/2*u)*sin(u) + 16*cos(u)^3 - 8*(4*cos(u)^3 - 3*cos(u))*sin(3/2*u)^2 - 12*cos(u) - 1)*v^4 + 4*v^5 + 4*v^3 + v^2)*sqrt(v))

# %% [markdown]
# ## Curvatura Gaussiana (k)

# %%
k_maeder = (e*g - f^2)/(E*G - F^2)
k_maeder
# Out:
# ((3*((v^2*cos(2*u) + v*cos(u))*(v*cos(2*u) - cos(u)) + (v^2*sin(2*u) - v*sin(u))*(v*sin(2*u) + sin(u)))*sqrt(v)*sin(3/2*u)/sqrt(((v^2*cos(2*u) + v*cos(u))*(v*cos(2*u) - cos(u)) + (v^2*sin(2*u) - v*sin(u))*(v*sin(2*u) + sin(u)))^2 + abs(2*(v*cos(2*u) - cos(u))*v^(3/2)*sin(3/2*u) - 2*(v^2*sin(2*u) - v*sin(u))*sqrt(v)*cos(3/2*u))^2 + abs(-2*(v*sin(2*u) + sin(u))*v^(3/2)*sin(3/2*u) - 2*(v^2*cos(2*u) + v*cos(u))*sqrt(v)*cos(3/2*u))^2) - 2*((v*cos(2*u) - cos(u))*v^(3/2)*sin(3/2*u) - (v^2*sin(2*u) - v*sin(u))*sqrt(v)*cos(3/2*u))*(2*v*cos(2*u) + cos(u))/sqrt(((v^2*cos(2*u) + v*cos(u))*(v*cos(2*u) - cos(u)) + (v^2*sin(2*u) - v*sin(u))*(v*sin(2*u) + sin(u)))^2 + abs(2*(v*cos(2*u) - cos(u))*v^(3/2)*sin(3/2*u) - 2*(v^2*sin(2*u) - v*sin(u))*sqrt(v)*cos(3/2*u))^2 + abs(-2*(v*sin(2*u) + sin(u))*v^(3/2)*sin(3/2*u) - 2*(v^2*cos(2*u) + v*cos(u))*sqrt(v)*cos(3/2*u))^2) - 2*((v*sin(2*u) + sin(u))*v^(3/2)*sin(3/2*u) + (v^2*cos(2*u) + v*cos(u))*sqrt(v)*cos(3/2*u))*(2*v*sin(2*u) - sin(u))/sqrt(((v^2*cos(2*u) + v*cos(u))*(v*cos(2*u) - cos(u)) + (v^2*sin(2*u) - v*sin(u))*(v*sin(2*u) + sin(u)))^2 + abs(2*(v*cos(2*u) - cos(u))*v^(3/2)*sin(3/2*u) - 2*(v^2*sin(2*u) - v*sin(u))*sqrt(v)*cos(3/2*u))^2 + abs(-2*(v*sin(2*u) + sin(u))*v^(3/2)*sin(3/2*u) - 2*(v^2*cos(2*u) + v*cos(u))*sqrt(v)*cos(3/2*u))^2))^2 - (3*((v^2*cos(2*u) + v*cos(u))*(v*cos(2*u) - cos(u)) + (v^2*sin(2*u) - v*sin(u))*(v*sin(2*u) + sin(u)))*v^(3/2)*cos(3/2*u)/sqrt(((v^2*cos(2*u) + v*cos(u))*(v*cos(2*u) - cos(u)) + (v^2*sin(2*u) - v*sin(u))*(v*sin(2*u) + sin(u)))^2 + abs(2*(v*cos(2*u) - cos(u))*v^(3/2)*sin(3/2*u) - 2*(v^2*sin(2*u) - v*sin(u))*sqrt(v)*cos(3/2*u))^2 + abs(-2*(v*sin(2*u) + sin(u))*v^(3/2)*sin(3/2*u) - 2*(v^2*cos(2*u) + v*cos(u))*sqrt(v)*cos(3/2*u))^2) - 2*((v*sin(2*u) + sin(u))*v^(3/2)*sin(3/2*u) + (v^2*cos(2*u) + v*cos(u))*sqrt(v)*cos(3/2*u))*(2*v^2*cos(2*u) - v*cos(u))/sqrt(((v^2*cos(2*u) + v*cos(u))*(v*cos(2*u) - cos(u)) + (v^2*sin(2*u) - v*sin(u))*(v*sin(2*u) + sin(u)))^2 + abs(2*(v*cos(2*u) - cos(u))*v^(3/2)*sin(3/2*u) - 2*(v^2*sin(2*u) - v*sin(u))*sqrt(v)*cos(3/2*u))^2 + abs(-2*(v*sin(2*u) + sin(u))*v^(3/2)*sin(3/2*u) - 2*(v^2*cos(2*u) + v*cos(u))*sqrt(v)*cos(3/2*u))^2) + 2*((v*cos(2*u) - cos(u))*v^(3/2)*sin(3/2*u) - (v^2*sin(2*u) - v*sin(u))*sqrt(v)*cos(3/2*u))*(2*v^2*sin(2*u) + v*sin(u))/sqrt(((v^2*cos(2*u) + v*cos(u))*(v*cos(2*u) - cos(u)) + (v^2*sin(2*u) - v*sin(u))*(v*sin(2*u) + sin(u)))^2 + abs(2*(v*cos(2*u) - cos(u))*v^(3/2)*sin(3/2*u) - 2*(v^2*sin(2*u) - v*sin(u))*sqrt(v)*cos(3/2*u))^2 + abs(-2*(v*sin(2*u) + sin(u))*v^(3/2)*sin(3/2*u) - 2*(v^2*cos(2*u) + v*cos(u))*sqrt(v)*cos(3/2*u))^2))*(2*((v*sin(2*u) + sin(u))*v^(3/2)*sin(3/2*u) + (v^2*cos(2*u) + v*cos(u))*sqrt(v)*cos(3/2*u))*cos(2*u)/sqrt(((v^2*cos(2*u) + v*cos(u))*(v*cos(2*u) - cos(u)) + (v^2*sin(2*u) - v*sin(u))*(v*sin(2*u) + sin(u)))^2 + abs(2*(v*cos(2*u) - cos(u))*v^(3/2)*sin(3/2*u) - 2*(v^2*sin(2*u) - v*sin(u))*sqrt(v)*cos(3/2*u))^2 + abs(-2*(v*sin(2*u) + sin(u))*v^(3/2)*sin(3/2*u) - 2*(v^2*cos(2*u) + v*cos(u))*sqrt(v)*cos(3/2*u))^2) - 2*((v*cos(2*u) - cos(u))*v^(3/2)*sin(3/2*u) - (v^2*sin(2*u) - v*sin(u))*sqrt(v)*cos(3/2*u))*sin(2*u)/sqrt(((v^2*cos(2*u) + v*cos(u))*(v*cos(2*u) - cos(u)) + (v^2*sin(2*u) - v*sin(u))*(v*sin(2*u) + sin(u)))^2 + abs(2*(v*cos(2*u) - cos(u))*v^(3/2)*sin(3/2*u) - 2*(v^2*sin(2*u) - v*sin(u))*sqrt(v)*cos(3/2*u))^2 + abs(-2*(v*sin(2*u) + sin(u))*v^(3/2)*sin(3/2*u) - 2*(v^2*cos(2*u) + v*cos(u))*sqrt(v)*cos(3/2*u))^2) - ((v^2*cos(2*u) + v*cos(u))*(v*cos(2*u) - cos(u)) + (v^2*sin(2*u) - v*sin(u))*(v*sin(2*u) + sin(u)))*cos(3/2*u)/(sqrt(((v^2*cos(2*u) + v*cos(u))*(v*cos(2*u) - cos(u)) + (v^2*sin(2*u) - v*sin(u))*(v*sin(2*u) + sin(u)))^2 + abs(2*(v*cos(2*u) - cos(u))*v^(3/2)*sin(3/2*u) - 2*(v^2*sin(2*u) - v*sin(u))*sqrt(v)*cos(3/2*u))^2 + abs(-2*(v*sin(2*u) + sin(u))*v^(3/2)*sin(3/2*u) - 2*(v^2*cos(2*u) + v*cos(u))*sqrt(v)*cos(3/2*u))^2)*sqrt(v))))/((4*v^2*cos(3/2*u)*sin(3/2*u) + (v^2*sin(2*u) - v*sin(u))*(v*cos(2*u) - cos(u)) - (v^2*cos(2*u) + v*cos(u))*(v*sin(2*u) + sin(u)))^2 - (4*v^ ...

# %%
k_maeder_simple = k_maeder.simplify_full()
k_maeder_simple
# Out:
# -(4*(2*(4*cos(u)^2 - 1)*cos(3/2*u)*sin(3/2*u)*sin(u) + 2*(4*cos(u)^3 - 3*cos(u))*cos(3/2*u)^2 - 4*cos(u)^3 + 3*cos(u))*v^3 + v^4 + 4*(2*(4*cos(u)^2 - 1)*cos(3/2*u)*sin(3/2*u)*sin(u) + 2*(4*cos(u)^3 - 3*cos(u))*cos(3/2*u)^2 - 4*cos(u)^3 + 3*cos(u))*v + 6*v^2 + 1)/(v^9 + 4*(8*(4*cos(u)^2 - 1)*cos(3/2*u)*sin(3/2*u)*sin(u) + 8*(4*cos(u)^3 - 3*cos(u))*cos(3/2*u)^2 - 16*cos(u)^3 + 12*cos(u) + 3)*v^7 + 8*v^8 + 8*(16*(4*cos(u)^2 - 1)*cos(3/2*u)*sin(3/2*u)*sin(u) + 16*(4*cos(u)^3 - 3*cos(u))*cos(3/2*u)^2 - 32*cos(u)^3 + 24*cos(u) - 1)*v^6 + 2*(512*cos(u)^6 + 128*(32*cos(u)^6 - 48*cos(u)^4 + 18*cos(u)^2 - 1)*cos(3/2*u)^4 - 768*cos(u)^4 - 32*(128*cos(u)^6 - 192*cos(u)^4 + 4*cos(u)^3 + 72*cos(u)^2 - 3*cos(u) - 4)*cos(3/2*u)^2 + 64*cos(u)^3 + 288*cos(u)^2 + 32*(8*(16*cos(u)^5 - 16*cos(u)^3 + 3*cos(u))*cos(3/2*u)^3*sin(u) - (64*cos(u)^5 - 64*cos(u)^3 + 4*cos(u)^2 + 12*cos(u) - 1)*cos(3/2*u)*sin(u))*sin(3/2*u) - 48*cos(u) + 19)*v^5 + 8*(16*(4*cos(u)^2 - 1)*cos(3/2*u)*sin(3/2*u)*sin(u) + 16*(4*cos(u)^3 - 3*cos(u))*cos(3/2*u)^2 - 32*cos(u)^3 + 24*cos(u) - 1)*v^4 + 4*(8*(4*cos(u)^2 - 1)*cos(3/2*u)*sin(3/2*u)*sin(u) + 8*(4*cos(u)^3 - 3*cos(u))*cos(3/2*u)^2 - 16*cos(u)^3 + 12*cos(u) + 3)*v^3 + 8*v^2 + v)

# %% [markdown]
# ## Curvatura Média (H)

# %%
H_maeder = (e*G - 2*f*F + g*E)/(2*(E*G - F^2))
H_maeder
# Out:
# -1/2*((3*((v^2*cos(2*u) + v*cos(u))*(v*cos(2*u) - cos(u)) + (v^2*sin(2*u) - v*sin(u))*(v*sin(2*u) + sin(u)))*v^(3/2)*cos(3/2*u)/sqrt(((v^2*cos(2*u) + v*cos(u))*(v*cos(2*u) - cos(u)) + (v^2*sin(2*u) - v*sin(u))*(v*sin(2*u) + sin(u)))^2 + abs(2*(v*cos(2*u) - cos(u))*v^(3/2)*sin(3/2*u) - 2*(v^2*sin(2*u) - v*sin(u))*sqrt(v)*cos(3/2*u))^2 + abs(-2*(v*sin(2*u) + sin(u))*v^(3/2)*sin(3/2*u) - 2*(v^2*cos(2*u) + v*cos(u))*sqrt(v)*cos(3/2*u))^2) - 2*((v*sin(2*u) + sin(u))*v^(3/2)*sin(3/2*u) + (v^2*cos(2*u) + v*cos(u))*sqrt(v)*cos(3/2*u))*(2*v^2*cos(2*u) - v*cos(u))/sqrt(((v^2*cos(2*u) + v*cos(u))*(v*cos(2*u) - cos(u)) + (v^2*sin(2*u) - v*sin(u))*(v*sin(2*u) + sin(u)))^2 + abs(2*(v*cos(2*u) - cos(u))*v^(3/2)*sin(3/2*u) - 2*(v^2*sin(2*u) - v*sin(u))*sqrt(v)*cos(3/2*u))^2 + abs(-2*(v*sin(2*u) + sin(u))*v^(3/2)*sin(3/2*u) - 2*(v^2*cos(2*u) + v*cos(u))*sqrt(v)*cos(3/2*u))^2) + 2*((v*cos(2*u) - cos(u))*v^(3/2)*sin(3/2*u) - (v^2*sin(2*u) - v*sin(u))*sqrt(v)*cos(3/2*u))*(2*v^2*sin(2*u) + v*sin(u))/sqrt(((v^2*cos(2*u) + v*cos(u))*(v*cos(2*u) - cos(u)) + (v^2*sin(2*u) - v*sin(u))*(v*sin(2*u) + sin(u)))^2 + abs(2*(v*cos(2*u) - cos(u))*v^(3/2)*sin(3/2*u) - 2*(v^2*sin(2*u) - v*sin(u))*sqrt(v)*cos(3/2*u))^2 + abs(-2*(v*sin(2*u) + sin(u))*v^(3/2)*sin(3/2*u) - 2*(v^2*cos(2*u) + v*cos(u))*sqrt(v)*cos(3/2*u))^2))*(4*v*cos(3/2*u)^2 + (v*cos(2*u) - cos(u))^2 + (v*sin(2*u) + sin(u))^2) + 2*(4*v^2*cos(3/2*u)*sin(3/2*u) + (v^2*sin(2*u) - v*sin(u))*(v*cos(2*u) - cos(u)) - (v^2*cos(2*u) + v*cos(u))*(v*sin(2*u) + sin(u)))*(3*((v^2*cos(2*u) + v*cos(u))*(v*cos(2*u) - cos(u)) + (v^2*sin(2*u) - v*sin(u))*(v*sin(2*u) + sin(u)))*sqrt(v)*sin(3/2*u)/sqrt(((v^2*cos(2*u) + v*cos(u))*(v*cos(2*u) - cos(u)) + (v^2*sin(2*u) - v*sin(u))*(v*sin(2*u) + sin(u)))^2 + abs(2*(v*cos(2*u) - cos(u))*v^(3/2)*sin(3/2*u) - 2*(v^2*sin(2*u) - v*sin(u))*sqrt(v)*cos(3/2*u))^2 + abs(-2*(v*sin(2*u) + sin(u))*v^(3/2)*sin(3/2*u) - 2*(v^2*cos(2*u) + v*cos(u))*sqrt(v)*cos(3/2*u))^2) - 2*((v*cos(2*u) - cos(u))*v^(3/2)*sin(3/2*u) - (v^2*sin(2*u) - v*sin(u))*sqrt(v)*cos(3/2*u))*(2*v*cos(2*u) + cos(u))/sqrt(((v^2*cos(2*u) + v*cos(u))*(v*cos(2*u) - cos(u)) + (v^2*sin(2*u) - v*sin(u))*(v*sin(2*u) + sin(u)))^2 + abs(2*(v*cos(2*u) - cos(u))*v^(3/2)*sin(3/2*u) - 2*(v^2*sin(2*u) - v*sin(u))*sqrt(v)*cos(3/2*u))^2 + abs(-2*(v*sin(2*u) + sin(u))*v^(3/2)*sin(3/2*u) - 2*(v^2*cos(2*u) + v*cos(u))*sqrt(v)*cos(3/2*u))^2) - 2*((v*sin(2*u) + sin(u))*v^(3/2)*sin(3/2*u) + (v^2*cos(2*u) + v*cos(u))*sqrt(v)*cos(3/2*u))*(2*v*sin(2*u) - sin(u))/sqrt(((v^2*cos(2*u) + v*cos(u))*(v*cos(2*u) - cos(u)) + (v^2*sin(2*u) - v*sin(u))*(v*sin(2*u) + sin(u)))^2 + abs(2*(v*cos(2*u) - cos(u))*v^(3/2)*sin(3/2*u) - 2*(v^2*sin(2*u) - v*sin(u))*sqrt(v)*cos(3/2*u))^2 + abs(-2*(v*sin(2*u) + sin(u))*v^(3/2)*sin(3/2*u) - 2*(v^2*cos(2*u) + v*cos(u))*sqrt(v)*cos(3/2*u))^2)) + (4*v^3*sin(3/2*u)^2 + (v^2*cos(2*u) + v*cos(u))^2 + (v^2*sin(2*u) - v*sin(u))^2)*(2*((v*sin(2*u) + sin(u))*v^(3/2)*sin(3/2*u) + (v^2*cos(2*u) + v*cos(u))*sqrt(v)*cos(3/2*u))*cos(2*u)/sqrt(((v^2*cos(2*u) + v*cos(u))*(v*cos(2*u) - cos(u)) + (v^2*sin(2*u) - v*sin(u))*(v*sin(2*u) + sin(u)))^2 + abs(2*(v*cos(2*u) - cos(u))*v^(3/2)*sin(3/2*u) - 2*(v^2*sin(2*u) - v*sin(u))*sqrt(v)*cos(3/2*u))^2 + abs(-2*(v*sin(2*u) + sin(u))*v^(3/2)*sin(3/2*u) - 2*(v^2*cos(2*u) + v*cos(u))*sqrt(v)*cos(3/2*u))^2) - 2*((v*cos(2*u) - cos(u))*v^(3/2)*sin(3/2*u) - (v^2*sin(2*u) - v*sin(u))*sqrt(v)*cos(3/2*u))*sin(2*u)/sqrt(((v^2*cos(2*u) + v*cos(u))*(v*cos(2*u) - cos(u)) + (v^2*sin(2*u) - v*sin(u))*(v*sin(2*u) + sin(u)))^2 + abs(2*(v*cos(2*u) - cos(u))*v^(3/2)*sin(3/2*u) - 2*(v^2*sin(2*u) - v*sin(u))*sqrt(v)*cos(3/2*u))^2 + abs(-2*(v*sin(2*u) + sin(u))*v^(3/2)*sin(3/2*u) - 2*(v^2*cos(2*u) + v*cos(u))*sqrt(v)*cos(3/2*u))^2) - ((v^2*cos(2*u) + v*cos(u))*(v*cos(2*u) - cos(u)) + (v^2*sin(2*u) - v*sin(u))*(v*sin(2*u) + sin(u)))*cos(3/2*u)/(sqrt(((v^2*cos(2*u) + v*cos(u))*(v*cos(2*u) - cos(u)) + (v^2*sin(2*u) - v*sin(u))*(v*sin(2*u) + sin(u)))^2 + abs(2*(v*cos(2*u) - cos(u))*v^(3/2)*sin(3/2*u) - 2*(v^2*sin(2*u) ...

# %%
H_maeder_simple = H_maeder.simplify_full()
H_maeder_simple
# Out:
# 2*(((4*cos(u)^2 - 1)*sin(3/2*u)*sin(u) + (4*cos(u)^3 - 3*cos(u) - 1)*cos(3/2*u))*v^4 - 2*(4*(4*cos(u)^3 - 3*cos(u))*cos(3/2*u)^3 - (12*cos(u)^3 - 9*cos(u) + 1)*cos(3/2*u) + (4*(4*cos(u)^2 - 1)*cos(3/2*u)^2*sin(u) - (4*cos(u)^2 - 1)*sin(u))*sin(3/2*u))*v^3 + ((4*cos(u)^2 - 1)*sin(3/2*u)*sin(u) + (4*cos(u)^3 - 3*cos(u) - 1)*cos(3/2*u))*v^2)/(sqrt(v^6 + 2*(8*(4*cos(u)^2 - 1)*cos(3/2*u)*sin(3/2*u)*sin(u) + 16*cos(u)^3 - 8*(4*cos(u)^3 - 3*cos(u))*sin(3/2*u)^2 - 12*cos(u) - 1)*v^4 + 4*v^5 + 4*v^3 + v^2)*(v^4 + 2*(8*(4*cos(u)^2 - 1)*cos(3/2*u)*sin(3/2*u)*sin(u) + 16*cos(u)^3 - 8*(4*cos(u)^3 - 3*cos(u))*sin(3/2*u)^2 - 12*cos(u) - 1)*v^2 + 4*v^3 + 4*v + 1)*sqrt(v))

# %% [markdown]
# ## Enneper:

# %%
u, v = var('u,v', domain='real')
f = u - (u^3)/3 + u*(v^2)
g = v - (v^3)/3 + v*(u^2)
h = u^2 - v^2
Enneper = ParametrizedSurface3D((f, g, h), (u, v)); Enneper
parametric_plot3d((f, g, h), (u,-5, 5), (v,-5, 5), color = 'lime')
# Out:
# Graphics3d Object

# %%
u, v = var('u, v')
f = u - (u^3)/3 + u*(v^2)
g = -v + (v^3)/3 - v*(u^2)
h = u^2 - v^2

print('f = u - (u^3)/3 + u*(v^2)')
print('g = -v + (v^3)/3 - v*(u^2)')
print('h = u^2 - v^2')

print(' ')
print('-------------------------------------------')
print(' ')

X_u = vector([diff(f, u), diff(g, u), diff(h, u)])
print(f'Primeira derivada (X_u): {X_u}')
print(' ')

X_uu = vector([diff(f, u, 2), diff(g, u, 2), diff(h, u, 2)])
print(f'Segunda derivada (X_uu): {X_uu}')


print(' ')
print('-------------------------------------------')
print(' ')

X_v = vector([diff(f, v), diff(g, v), diff(h, v)])
print(f'Primeira derivada (X_v): {X_v}')
print(' ')

X_vv = vector([diff(f, v, 2), diff(g, v, 2), diff(h, v, 2)])
print(f'Segunda derivada (X_vv): {X_vv}')

print(' ')
print('-------------------------------------------')
print(' ')

X_uv = vector([diff(f, u, v), diff(g, u, v), diff(h, u, v)])
print(f'Segunda derivada (X_uv): {X_uv}')
print(' ')

X_vu = vector([diff(f, v, u), diff(g, v, u), diff(h, v, u)])
print(f'Segunda derivada (X_vu): {X_vu}')
print(' ')
# Out:
# f = u - (u^3)/3 + u*(v^2)
# g = -v + (v^3)/3 - v*(u^2)
# h = u^2 - v^2
#
# -------------------------------------------
#
# Primeira derivada (X_u): (-u^2 + v^2 + 1, -2*u*v, 2*u)
#
# Segunda derivada (X_uu): (-2*u, -2*v, 2)
#
# -------------------------------------------
#
# Primeira derivada (X_v): (2*u*v, -u^2 + v^2 - 1, -2*v)
#
# Segunda derivada (X_vv): (2*u, 2*v, -2)
#
# -------------------------------------------
#
# Segunda derivada (X_uv): (2*v, -2*u, 0)
#
# Segunda derivada (X_vu): (2*v, -2*u, 0)

# %%
E = X_u.dot_product(X_u)
E
# Out:
# 4*u^2*v^2 + (u^2 - v^2 - 1)^2 + 4*u^2

# %%
E_simple = E.simplify_full()
E_simple
# Out:
# u^4 + v^4 + 2*(u^2 + 1)*v^2 + 2*u^2 + 1

# %%
F = X_u.dot_product(X_v)
F
# Out:
# 2*(u^2 - v^2 + 1)*u*v - 2*(u^2 - v^2 - 1)*u*v - 4*u*v

# %%
F_simple = F.simplify_full()
F_simple
# Out:
# 0

# %%
G = X_v.dot_product(X_v)
G
# Out:
# 4*u^2*v^2 + (u^2 - v^2 + 1)^2 + 4*v^2

# %%
G_simple = G.simplify_full()
G_simple
# Out:
# u^4 + v^4 + 2*(u^2 + 1)*v^2 + 2*u^2 + 1

# %%
cross_enneper = X_u.cross_product(X_v)
cross_enneper
# Out:
# (4*u*v^2 + 2*(u^2 - v^2 + 1)*u, 4*u^2*v - 2*(u^2 - v^2 - 1)*v, 4*u^2*v^2 + (u^2 - v^2 + 1)*(u^2 - v^2 - 1))

# %%
cross_enneper_simple = cross_enneper.simplify_full()
cross_enneper_simple
# Out:
# (2*u^3 + 2*u*v^2 + 2*u, 2*v^3 + 2*(u^2 + 1)*v, u^4 + 2*u^2*v^2 + v^4 - 1)

# %%
cross_enneper_norm = cross_enneper.norm(2)
cross_enneper_norm
# Out:
# sqrt((4*u^2*v^2 + (u^2 - v^2 + 1)*(u^2 - v^2 - 1))^2 + 4*(2*u^2*v - (u^2 - v^2 - 1)*v)^2 + 4*(2*u*v^2 + (u^2 - v^2 + 1)*u)^2)

# %%
cross_enneper_norm_simple = cross_enneper_norm.simplify_full()
cross_enneper_norm_simple
# Out:
# sqrt(u^8 + v^8 + 4*(u^2 + 1)*v^6 + 4*u^6 + 6*(u^4 + 2*u^2 + 1)*v^4 + 6*u^4 + 4*(u^6 + 3*u^4 + 3*u^2 + 1)*v^2 + 4*u^2 + 1)

# %%
N = (cross_enneper)/(cross_enneper_norm)
N
# Out:
# (2*(2*u*v^2 + (u^2 - v^2 + 1)*u)/sqrt((4*u^2*v^2 + (u^2 - v^2 + 1)*(u^2 - v^2 - 1))^2 + 4*(2*u^2*v - (u^2 - v^2 - 1)*v)^2 + 4*(2*u*v^2 + (u^2 - v^2 + 1)*u)^2), 2*(2*u^2*v - (u^2 - v^2 - 1)*v)/sqrt((4*u^2*v^2 + (u^2 - v^2 + 1)*(u^2 - v^2 - 1))^2 + 4*(2*u^2*v - (u^2 - v^2 - 1)*v)^2 + 4*(2*u*v^2 + (u^2 - v^2 + 1)*u)^2), (4*u^2*v^2 + (u^2 - v^2 + 1)*(u^2 - v^2 - 1))/sqrt((4*u^2*v^2 + (u^2 - v^2 + 1)*(u^2 - v^2 - 1))^2 + 4*(2*u^2*v - (u^2 - v^2 - 1)*v)^2 + 4*(2*u*v^2 + (u^2 - v^2 + 1)*u)^2))

# %%
N_simple = N.simplify_full()
N_simple
# Out:
# (2*(u^3 + u*v^2 + u)/sqrt(u^8 + v^8 + 4*(u^2 + 1)*v^6 + 4*u^6 + 6*(u^4 + 2*u^2 + 1)*v^4 + 6*u^4 + 4*(u^6 + 3*u^4 + 3*u^2 + 1)*v^2 + 4*u^2 + 1), 2*(v^3 + (u^2 + 1)*v)/sqrt(u^8 + v^8 + 4*(u^2 + 1)*v^6 + 4*u^6 + 6*(u^4 + 2*u^2 + 1)*v^4 + 6*u^4 + 4*(u^6 + 3*u^4 + 3*u^2 + 1)*v^2 + 4*u^2 + 1), (u^4 + 2*u^2*v^2 + v^4 - 1)/sqrt(u^8 + v^8 + 4*(u^2 + 1)*v^6 + 4*u^6 + 6*(u^4 + 2*u^2 + 1)*v^4 + 6*u^4 + 4*(u^6 + 3*u^4 + 3*u^2 + 1)*v^2 + 4*u^2 + 1))

# %%
e = N.dot_product(X_uu)
e
# Out:
# -4*(2*u*v^2 + (u^2 - v^2 + 1)*u)*u/sqrt((4*u^2*v^2 + (u^2 - v^2 + 1)*(u^2 - v^2 - 1))^2 + 4*(2*u^2*v - (u^2 - v^2 - 1)*v)^2 + 4*(2*u*v^2 + (u^2 - v^2 + 1)*u)^2) - 4*(2*u^2*v - (u^2 - v^2 - 1)*v)*v/sqrt((4*u^2*v^2 + (u^2 - v^2 + 1)*(u^2 - v^2 - 1))^2 + 4*(2*u^2*v - (u^2 - v^2 - 1)*v)^2 + 4*(2*u*v^2 + (u^2 - v^2 + 1)*u)^2) + 2*(4*u^2*v^2 + (u^2 - v^2 + 1)*(u^2 - v^2 - 1))/sqrt((4*u^2*v^2 + (u^2 - v^2 + 1)*(u^2 - v^2 - 1))^2 + 4*(2*u^2*v - (u^2 - v^2 - 1)*v)^2 + 4*(2*u*v^2 + (u^2 - v^2 + 1)*u)^2)

# %%
e_simple = e.simplify_full()
e_simple
# Out:
# -2*(u^4 + v^4 + 2*(u^2 + 1)*v^2 + 2*u^2 + 1)/sqrt(u^8 + v^8 + 4*(u^2 + 1)*v^6 + 4*u^6 + 6*(u^4 + 2*u^2 + 1)*v^4 + 6*u^4 + 4*(u^6 + 3*u^4 + 3*u^2 + 1)*v^2 + 4*u^2 + 1)

# %%
f = N.dot_product(X_uv)
f
# Out:
# -4*(2*u^2*v - (u^2 - v^2 - 1)*v)*u/sqrt((4*u^2*v^2 + (u^2 - v^2 + 1)*(u^2 - v^2 - 1))^2 + 4*(2*u^2*v - (u^2 - v^2 - 1)*v)^2 + 4*(2*u*v^2 + (u^2 - v^2 + 1)*u)^2) + 4*(2*u*v^2 + (u^2 - v^2 + 1)*u)*v/sqrt((4*u^2*v^2 + (u^2 - v^2 + 1)*(u^2 - v^2 - 1))^2 + 4*(2*u^2*v - (u^2 - v^2 - 1)*v)^2 + 4*(2*u*v^2 + (u^2 - v^2 + 1)*u)^2)

# %%
f_simple = f.simplify_full()
f_simple
# Out:
# 0

# %%
g = N.dot_product(X_vv)
g
# Out:
# 4*(2*u*v^2 + (u^2 - v^2 + 1)*u)*u/sqrt((4*u^2*v^2 + (u^2 - v^2 + 1)*(u^2 - v^2 - 1))^2 + 4*(2*u^2*v - (u^2 - v^2 - 1)*v)^2 + 4*(2*u*v^2 + (u^2 - v^2 + 1)*u)^2) + 4*(2*u^2*v - (u^2 - v^2 - 1)*v)*v/sqrt((4*u^2*v^2 + (u^2 - v^2 + 1)*(u^2 - v^2 - 1))^2 + 4*(2*u^2*v - (u^2 - v^2 - 1)*v)^2 + 4*(2*u*v^2 + (u^2 - v^2 + 1)*u)^2) - 2*(4*u^2*v^2 + (u^2 - v^2 + 1)*(u^2 - v^2 - 1))/sqrt((4*u^2*v^2 + (u^2 - v^2 + 1)*(u^2 - v^2 - 1))^2 + 4*(2*u^2*v - (u^2 - v^2 - 1)*v)^2 + 4*(2*u*v^2 + (u^2 - v^2 + 1)*u)^2)

# %%
g_simple = g.simplify_full()
g_simple
# Out:
# 2*(u^4 + v^4 + 2*(u^2 + 1)*v^2 + 2*u^2 + 1)/sqrt(u^8 + v^8 + 4*(u^2 + 1)*v^6 + 4*u^6 + 6*(u^4 + 2*u^2 + 1)*v^4 + 6*u^4 + 4*(u^6 + 3*u^4 + 3*u^2 + 1)*v^2 + 4*u^2 + 1)

# %% [markdown]
# ## Curvatura Gaussiana (k)

# %%
k_enneper = (e*g - f^2)/(E*G - F^2)
k_enneper
# Out:
# -4*(4*((2*u^2*v - (u^2 - v^2 - 1)*v)*u/sqrt((4*u^2*v^2 + (u^2 - v^2 + 1)*(u^2 - v^2 - 1))^2 + 4*(2*u^2*v - (u^2 - v^2 - 1)*v)^2 + 4*(2*u*v^2 + (u^2 - v^2 + 1)*u)^2) - (2*u*v^2 + (u^2 - v^2 + 1)*u)*v/sqrt((4*u^2*v^2 + (u^2 - v^2 + 1)*(u^2 - v^2 - 1))^2 + 4*(2*u^2*v - (u^2 - v^2 - 1)*v)^2 + 4*(2*u*v^2 + (u^2 - v^2 + 1)*u)^2))^2 + (2*(2*u*v^2 + (u^2 - v^2 + 1)*u)*u/sqrt((4*u^2*v^2 + (u^2 - v^2 + 1)*(u^2 - v^2 - 1))^2 + 4*(2*u^2*v - (u^2 - v^2 - 1)*v)^2 + 4*(2*u*v^2 + (u^2 - v^2 + 1)*u)^2) + 2*(2*u^2*v - (u^2 - v^2 - 1)*v)*v/sqrt((4*u^2*v^2 + (u^2 - v^2 + 1)*(u^2 - v^2 - 1))^2 + 4*(2*u^2*v - (u^2 - v^2 - 1)*v)^2 + 4*(2*u*v^2 + (u^2 - v^2 + 1)*u)^2) - (4*u^2*v^2 + (u^2 - v^2 + 1)*(u^2 - v^2 - 1))/sqrt((4*u^2*v^2 + (u^2 - v^2 + 1)*(u^2 - v^2 - 1))^2 + 4*(2*u^2*v - (u^2 - v^2 - 1)*v)^2 + 4*(2*u*v^2 + (u^2 - v^2 + 1)*u)^2))^2)/((4*u^2*v^2 + (u^2 - v^2 + 1)^2 + 4*v^2)*(4*u^2*v^2 + (u^2 - v^2 - 1)^2 + 4*u^2) - 4*((u^2 - v^2 + 1)*u*v - (u^2 - v^2 - 1)*u*v - 2*u*v)^2)

# %%
k_enneper_simple = k_enneper.simplify_full()
k_enneper_simple
# Out:
# -4/(u^8 + v^8 + 4*(u^2 + 1)*v^6 + 4*u^6 + 6*(u^4 + 2*u^2 + 1)*v^4 + 6*u^4 + 4*(u^6 + 3*u^4 + 3*u^2 + 1)*v^2 + 4*u^2 + 1)

# %% [markdown]
# ## Curvatura Média (H)

# %%
H_enneper = (e*G - 2*f*F + g*E)/(2*(E*G - F^2))
H_enneper
# Out:
# (8*((u^2 - v^2 + 1)*u*v - (u^2 - v^2 - 1)*u*v - 2*u*v)*((2*u^2*v - (u^2 - v^2 - 1)*v)*u/sqrt((4*u^2*v^2 + (u^2 - v^2 + 1)*(u^2 - v^2 - 1))^2 + 4*(2*u^2*v - (u^2 - v^2 - 1)*v)^2 + 4*(2*u*v^2 + (u^2 - v^2 + 1)*u)^2) - (2*u*v^2 + (u^2 - v^2 + 1)*u)*v/sqrt((4*u^2*v^2 + (u^2 - v^2 + 1)*(u^2 - v^2 - 1))^2 + 4*(2*u^2*v - (u^2 - v^2 - 1)*v)^2 + 4*(2*u*v^2 + (u^2 - v^2 + 1)*u)^2)) - (4*u^2*v^2 + (u^2 - v^2 + 1)^2 + 4*v^2)*(2*(2*u*v^2 + (u^2 - v^2 + 1)*u)*u/sqrt((4*u^2*v^2 + (u^2 - v^2 + 1)*(u^2 - v^2 - 1))^2 + 4*(2*u^2*v - (u^2 - v^2 - 1)*v)^2 + 4*(2*u*v^2 + (u^2 - v^2 + 1)*u)^2) + 2*(2*u^2*v - (u^2 - v^2 - 1)*v)*v/sqrt((4*u^2*v^2 + (u^2 - v^2 + 1)*(u^2 - v^2 - 1))^2 + 4*(2*u^2*v - (u^2 - v^2 - 1)*v)^2 + 4*(2*u*v^2 + (u^2 - v^2 + 1)*u)^2) - (4*u^2*v^2 + (u^2 - v^2 + 1)*(u^2 - v^2 - 1))/sqrt((4*u^2*v^2 + (u^2 - v^2 + 1)*(u^2 - v^2 - 1))^2 + 4*(2*u^2*v - (u^2 - v^2 - 1)*v)^2 + 4*(2*u*v^2 + (u^2 - v^2 + 1)*u)^2)) + (4*u^2*v^2 + (u^2 - v^2 - 1)^2 + 4*u^2)*(2*(2*u*v^2 + (u^2 - v^2 + 1)*u)*u/sqrt((4*u^2*v^2 + (u^2 - v^2 + 1)*(u^2 - v^2 - 1))^2 + 4*(2*u^2*v - (u^2 - v^2 - 1)*v)^2 + 4*(2*u*v^2 + (u^2 - v^2 + 1)*u)^2) + 2*(2*u^2*v - (u^2 - v^2 - 1)*v)*v/sqrt((4*u^2*v^2 + (u^2 - v^2 + 1)*(u^2 - v^2 - 1))^2 + 4*(2*u^2*v - (u^2 - v^2 - 1)*v)^2 + 4*(2*u*v^2 + (u^2 - v^2 + 1)*u)^2) - (4*u^2*v^2 + (u^2 - v^2 + 1)*(u^2 - v^2 - 1))/sqrt((4*u^2*v^2 + (u^2 - v^2 + 1)*(u^2 - v^2 - 1))^2 + 4*(2*u^2*v - (u^2 - v^2 - 1)*v)^2 + 4*(2*u*v^2 + (u^2 - v^2 + 1)*u)^2)))/((4*u^2*v^2 + (u^2 - v^2 + 1)^2 + 4*v^2)*(4*u^2*v^2 + (u^2 - v^2 - 1)^2 + 4*u^2) - 4*((u^2 - v^2 + 1)*u*v - (u^2 - v^2 - 1)*u*v - 2*u*v)^2)

# %%
H_enneper_simple = H_enneper.simplify_full()
H_enneper_simple
# Out:
# 0
