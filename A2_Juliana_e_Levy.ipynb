# %% [markdown]
# # A2 - Curvas e Superfícies

# %% [markdown]
# ## Alunos: Juliana Carvalho e Raphael Levy

# %%
# %display latex

# %% [markdown]
# ## Helicoide:

# %%
u, v = var('u,v', domain='real')
Helicoide = ParametrizedSurface3D((v*cos(u), v*sin(u), u), (u, v)); Helicoide
parametric_plot3d((v*cos(u), v*sin(u), u), (u,0,3*pi), (v,-pi,pi))
# Out:
# Graphics3d Object

# %%
u, v = var('u, v')
f = v*cos(u)
g = v*sin(u)
h = u

print('Primeira derivada')
print(' ')
print(f'Derivada de v*cos(u): {diff(f, u)}')
print(f'Derivada de v*sin(u): {diff(g, u)}')
print(f'Derivada de u: {diff(h, u)}')

print('Segunda derivada')
print(' ')
print(f'Segunda derivada de v*cos(u): {diff(f, u, 2)}')
print(f'Segunda derivada de v*sin(u): {diff(g, u, 2)}')
print(f'Segunda derivada de u: {diff(h, u, 2)}')
# Out:
# Primeira derivada
#
# Derivada de v*cos(u): -v*sin(u)
# Derivada de v*sin(u): v*cos(u)
# Derivada de u: 1
# Segunda derivada
#
# Segunda derivada de v*cos(u): -v*cos(u)
# Segunda derivada de v*sin(u): -v*sin(u)
# Segunda derivada de u: 0

# %%
p = vector([-v*sin(u), v*cos(u), 1]); q = vector([-v*cos(u), -v*sin(u), 0])
r = p.cross_product(q); r
# Out:
# (v*sin(u), -v*cos(u), v^2*cos(u)^2 + v^2*sin(u)^2)

# %% [markdown]
# OBS: p = f'; q = f''

# %%
r.norm(2)
# Out:
# sqrt(v^2*cos(u)^2 + v^2*sin(u)^2 + (v^2*cos(u)^2 + v^2*sin(u)^2)^2)

# %%
(p.norm(2))^3
# Out:
# (v^2*cos(u)^2 + v^2*sin(u)^2 + 1)^(3/2)

# %%
k = r.norm(2)/((p.norm(2))^3)
k
# Out:
# sqrt(v^2*cos(u)^2 + v^2*sin(u)^2 + (v^2*cos(u)^2 + v^2*sin(u)^2)^2)/(v^2*cos(u)^2 + v^2*sin(u)^2 + 1)^(3/2)

# %%
u, v = var('u, v')
f = v*cos(u)
g = v*sin(u)
h = u

print('Primeira derivada')
print(' ')
print(f'Derivada de v*cos(u): {diff(f, v)}')
print(f'Derivada de v*sin(u): {diff(g, v)}')
print(f'Derivada de u: {diff(h, v)}')

print('Segunda derivada')
print(' ')
print(f'Segunda derivada de v*cos(u): {diff(f, v, 2)}')
print(f'Segunda derivada de v*sin(u): {diff(g, v, 2)}')
print(f'Segunda derivada de u: {diff(h, v, 2)}')
# Out:
# Primeira derivada
#
# Derivada de v*cos(u): cos(u)
# Derivada de v*sin(u): sin(u)
# Derivada de u: 0
# Segunda derivada
#
# Segunda derivada de v*cos(u): 0
# Segunda derivada de v*sin(u): 0
# Segunda derivada de u: 0

# %%
p = vector([cos(u), sin(u), 0]); q = vector([0, 0, 0])
r = p.cross_product(q); r
# Out:
# (0, 0, 0)

# %%
r.norm(2)
# Out:
# 0

# %%
(p.norm(2))^3
# Out:
# (cos(u)^2 + sin(u)^2)^(3/2)

# %%
k = r.norm(2)/((p.norm(2))^3)
k
# Out:
# 0

# %%
u, v = var('u,v', domain='real')
Helic = ParametrizedSurface3D((cos(u)*sinh(v), sinh(v)*sin(u), u), (u, v)); Helic
parametric_plot3d((cos(u)*sinh(v), sinh(v)*sin(u), u), (u,0,2*pi), (v,-pi/2,pi/2), color = 'red')
# Out:
# Graphics3d Object

# %%
u, v = var('u, v')
f = cos(u)*sinh(v)
g = sin(u)*sinh(v)
h = u

print('Primeira derivada')
print(' ')
print(f'Derivada de cos(u)*sinh(v): {diff(f, u)}')
print(f'Derivada de sin(u)*sinh(v): {diff(g, u)}')
print(f'Derivada de u: {diff(h, u)}')

print('Segunda derivada')
print(' ')
print(f'Segunda derivada de cos(u)*sinh(v): {diff(f, u, 2)}')
print(f'Segunda derivada de sin(u)*sinh(v): {diff(g, u, 2)}')
print(f'Segunda derivada de u: {diff(h, u, 2)}')
# Out:
# Primeira derivada
#
# Derivada de v*cos(u): -sin(u)*sinh(v)
# Derivada de v*sin(u): cos(u)*sinh(v)
# Derivada de u: 1
# Segunda derivada
#
# Segunda derivada de v*cos(u): -cos(u)*sinh(v)
# Segunda derivada de v*sin(u): -sin(u)*sinh(v)
# Segunda derivada de u: 0

# %%
p = vector([-sinh(v)*sin(u), sinh(v)*cos(u), 1]); q = vector([-sinh(v)*cos(u), -sinh(v)*sin(u), 0])
r = p.cross_product(q); r
# Out:
# (sin(u)*sinh(v), -cos(u)*sinh(v), cos(u)^2*sinh(v)^2 + sin(u)^2*sinh(v)^2)

# %%
r.norm(2)
# Out:
# sqrt(cos(u)^2*sinh(v)^2 + sin(u)^2*sinh(v)^2 + (cos(u)^2*sinh(v)^2 + sin(u)^2*sinh(v)^2)^2)

# %%
(p.norm(2))^3
# Out:
# (cos(u)^2*sinh(v)^2 + sin(u)^2*sinh(v)^2 + 1)^(3/2)

# %%
k = r.norm(2)/((p.norm(2))^3)
k
# Out:
# sqrt(cos(u)^2*sinh(v)^2 + sin(u)^2*sinh(v)^2 + (cos(u)^2*sinh(v)^2 + sin(u)^2*sinh(v)^2)^2)/(cos(u)^2*sinh(v)^2 + sin(u)^2*sinh(v)^2 + 1)^(3/2)

# %%
u, v = var('u, v')
f = cos(u)*sinh(v)
g = sin(u)*sinh(v)
h = u

print('Primeira derivada')
print(' ')
print(f'Derivada de cos(u)*sinh(v): {diff(f, v)}')
print(f'Derivada de sin(u)*sinh(v): {diff(g, v)}')
print(f'Derivada de u: {diff(h, v)}')

print('Segunda derivada')
print(' ')
print(f'Segunda derivada de cos(u)*sinh(v): {diff(f, v, 2)}')
print(f'Segunda derivada de sin(u)*sinh(v): {diff(g, v, 2)}')
print(f'Segunda derivada de u: {diff(h, v, 2)}')
# Out:
# Primeira derivada
#
# Derivada de v*cos(u): cos(u)*cosh(v)
# Derivada de v*sin(u): cosh(v)*sin(u)
# Derivada de u: 0
# Segunda derivada
#
# Segunda derivada de v*cos(u): cos(u)*sinh(v)
# Segunda derivada de v*sin(u): sin(u)*sinh(v)
# Segunda derivada de u: 0

# %%
p = vector([cos(u)*cosh(v), sin(u)*cosh(v), 0]); q = vector([sinh(v)*cos(u), sinh(v)*sin(u), 0])
r = p.cross_product(q); r
# Out:
# (0, 0, 0)

# %%
r.norm(2)
# Out:
# 0

# %%
(p.norm(2))^3
# Out:
# (cos(u)^2*cosh(v)^2 + cosh(v)^2*sin(u)^2)^(3/2)

# %%
k = r.norm(2)/((p.norm(2))^3)
k
# Out:
# 0

# %% [markdown]
# Derivando em função de $v$, achamos que a curvatura é 0 e portanto a helicoide é uma superfície mínima

# %% [markdown]
# ## Catenoide:

# %%
u, v = var('u,v', domain='real')
Catenoide = ParametrizedSurface3D((cos(u)*cosh(v), cosh(v)*sin(u), v), (u, v)); Catenoide
parametric_plot3d((cos(u)*cosh(v), cosh(v)*sin(u), v), (u,0,2*pi), (v,-pi/2,pi/2), color = 'green')
# Out:
# Graphics3d Object

# %%
u, v = var('u, v')
f = cos(u)*cosh(v)
g = sin(u)*cosh(v)
h = v

print('Primeira derivada')
print(' ')
print(f'Derivada de cos(u)*cosh(v): {diff(f, v)}')
print(f'Derivada de sin(u)*cosh(v): {diff(g, v)}')
print(f'Derivada de v: {diff(h, v)}')

print('Segunda derivada')
print(' ')
print(f'Segunda derivada de cos(u)*cosh(v): {diff(f, v, 2)}')
print(f'Segunda derivada de sin(u)*cosh(v): {diff(g, v, 2)}')
print(f'Segunda derivada de v: {diff(h, v, 2)}')
# Out:
# Primeira derivada
#
# Derivada de v*cos(u): cos(u)*sinh(v)
# Derivada de v*sin(u): sin(u)*sinh(v)
# Derivada de u: 1
# Segunda derivada
#
# Segunda derivada de v*cos(u): cos(u)*cosh(v)
# Segunda derivada de v*sin(u): cosh(v)*sin(u)
# Segunda derivada de u: 0

# %%
p = vector([cos(u)*cosh(v), sin(u)*cosh(v), 0]); q = vector([sinh(v)*cos(u), sinh(v)*sin(u), 0])
r = p.cross_product(q); r
# Out:
# (0, 0, 0)

# %%
r.norm(2)
# Out:
# 0

# %%
(p.norm(2))^3
# Out:
# (cos(u)^2*cosh(v)^2 + cosh(v)^2*sin(u)^2)^(3/2)

# %%
k = r.norm(2)/((p.norm(2))^3)
k
# Out:
# 0

# %% [markdown]
# Derivando em função de $v$, achamos que a curvatura é 0 e portanto a catenoide é uma superfície mínima

# %% [markdown]
# ## Esfera:

# %%
u, v = var('u,v', domain='real')
Esfera = ParametrizedSurface3D((sin(u)*cos(v), sin(u)*sin(v), cos(u)), (u, v)); Esfera
parametric_plot3d((sin(u)*cos(v), sin(u)*sin(v), cos(u)), (u,0,pi), (v,0, 2*pi), color = 'purple')
# Out:
# Graphics3d Object

# %%
u, v = var('u, v')
f = sin(u)*cos(v)
g = sin(u)*sin(v)
h = cos(u)

print('Primeira derivada')
print(' ')
print(f'Derivada de sin(u)*cos(v): {diff(f, v)}')
print(f'Derivada de sin(u)*sin(v): {diff(g, v)}')
print(f'Derivada de cos(u): {diff(h, v)}')

print('Segunda derivada')
print(' ')
print(f'Segunda derivada de sin(u)*cos(v): {diff(f, v, 2)}')
print(f'Segunda derivada de sin(u)*sin(v): {diff(g, v, 2)}')
print(f'Segunda derivada de cos(u): {diff(h, v, 2)}')
# Out:
# Primeira derivada
#
# Derivada de sin(u)*cos(v): -sin(u)*sin(v)
# Derivada de sin(u)*sin(v): cos(v)*sin(u)
# Derivada de cos(u): 0
# Segunda derivada
#
# Segunda derivada de sin(u)*cos(v): -cos(v)*sin(u)
# Segunda derivada de sin(u)*sin(v): -sin(u)*sin(v)
# Segunda derivada de cos(u): 0

# %%
p = vector([-sin(u)*sin(v), sin(u)*cos(v), 0]); q = vector([-cos(v)*sin(u), -sin(v)*sin(u), 0])
r = p.cross_product(q); r
# Out:
# (0, 0, cos(v)^2*sin(u)^2 + sin(u)^2*sin(v)^2)

# %%
r.norm(2)
# Out:
# cos(v)^2*sin(u)^2 + sin(u)^2*sin(v)^2

# %%
(p.norm(2))^3
# Out:
# (cos(v)^2*sin(u)^2 + sin(u)^2*sin(v)^2)^(3/2)

# %%
k = r.norm(2)/((p.norm(2))^3)
k
# Out:
# 1/sqrt(cos(v)^2*sin(u)^2 + sin(u)^2*sin(v)^2)

# %%
u, v = var('u, v')
f = sin(u)*cos(v)
g = sin(u)*sin(v)
h = cos(u)

print('Primeira derivada')
print(' ')
print(f'Derivada de sin(u)*cos(v): {diff(f, u)}')
print(f'Derivada de sin(u)*sin(v): {diff(g, u)}')
print(f'Derivada de cos(u): {diff(h, u)}')

print('Segunda derivada')
print(' ')
print(f'Segunda derivada de sin(u)*cos(v): {diff(f, u, 2)}')
print(f'Segunda derivada de sin(u)*sin(v): {diff(g, u, 2)}')
print(f'Segunda derivada de cos(u): {diff(h, u, 2)}')
# Out:
# Primeira derivada
#
# Derivada de sin(u)*cos(v): cos(u)*cos(v)
# Derivada de sin(u)*sin(v): cos(u)*sin(v)
# Derivada de cos(u): -sin(u)
# Segunda derivada
#
# Segunda derivada de sin(u)*cos(v): -cos(v)*sin(u)
# Segunda derivada de sin(u)*sin(v): -sin(u)*sin(v)
# Segunda derivada de cos(u): -cos(u)
